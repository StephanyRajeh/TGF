# %% [markdown]
# - First column: ID of from node
# - Second column: ID of to node
# - Third column (if present): weight or multiplicity of edge
# - Fourth column (if present):  timestamp of edges Unix time
#
# Note: The json file should be gzipped online

# %% [markdown]
# # Imports

# %%
import os
import ipdb
import argparse
import numpy as np
import pandas as pd
import numpy.random as random 
import networkx as nx
from progressbar import ProgressBar
import matplotlib.pyplot as plt
import gzip

# %% [markdown]
# ##  Taking raw network

# %%
# Get uci raw and convert it to uci.txt format (t, u, v)
cols = ['u','v','weight','timestamp']
data = pd.read_csv('tech-as-topology.edges', sep=" ",  names=cols, skiprows=(5))
data
# Out:
#            u      v  weight   timestamp
# 0          1      2       1  1266192000
# 1          3      4       1  1266474818
# 2          5      6       1  1266213618
# 3          7      8       1  1266238515
# 4          9     10       1  1266192000
# ...      ...    ...     ...         ...
# 171398   160    466       1  1266204900
# 171399   670  32351       1  1266192000
# 171400  1794   9116       1  1266192000
# 171401    53  11520       1  1266192000
# 171402  9752   6023       1  1266268751
#
# [171403 rows x 4 columns]

# %%
data.drop(columns=["weight"], inplace=True)
data
# Out:
#            u      v   timestamp
# 0          1      2  1266192000
# 1          3      4  1266474818
# 2          5      6  1266213618
# 3          7      8  1266238515
# 4          9     10  1266192000
# ...      ...    ...         ...
# 171398   160    466  1266204900
# 171399   670  32351  1266192000
# 171400  1794   9116  1266192000
# 171401    53  11520  1266192000
# 171402  9752   6023  1266268751
#
# [171403 rows x 3 columns]

# %%
# Changing the position of the columns
data = data[['timestamp', 'u', 'v']]
data
# Out:
#          timestamp     u      v
# 0       1266192000     1      2
# 1       1266474818     3      4
# 2       1266213618     5      6
# 3       1266238515     7      8
# 4       1266192000     9     10
# ...            ...   ...    ...
# 171398  1266204900   160    466
# 171399  1266192000   670  32351
# 171400  1266192000  1794   9116
# 171401  1266192000    53  11520
# 171402  1266268751  9752   6023
#
# [171403 rows x 3 columns]

# %%
data['timestamp'] = data['timestamp'].astype(int)
data
# Out:
#          timestamp     u      v
# 0       1266192000     1      2
# 1       1266474818     3      4
# 2       1266213618     5      6
# 3       1266238515     7      8
# 4       1266192000     9     10
# ...            ...   ...    ...
# 171398  1266204900   160    466
# 171399  1266192000   670  32351
# 171400  1266192000  1794   9116
# 171401  1266192000    53  11520
# 171402  1266268751  9752   6023
#
# [171403 rows x 3 columns]

# %%
# Find a duplicate rows in terms of timestamps
duplicateDFRow = data[data.duplicated(subset=['timestamp'])]
duplicateDFRow
# Out:
#          timestamp     u      v
# 4       1266192000     9     10
# 5       1266192000    11     12
# 7       1266192000    11     15
# 8       1266192000    16     17
# 10      1266192000    20     21
# ...            ...   ...    ...
# 171398  1266204900   160    466
# 171399  1266192000   670  32351
# 171400  1266192000  1794   9116
# 171401  1266192000    53  11520
# 171402  1266268751  9752   6023
#
# [138579 rows x 3 columns]

# %%
# Check how many occurances we have in every timestamp
timestamps_grouped = data.groupby('timestamp')[['u', 'v']].apply(lambda x: x.shape[0])
print(timestamps_grouped)
# Out:
# timestamp
# 1266192000    67010
# 1266192001       60
# 1266192002       22
# 1266192003       13
# 1266192004       11
#               ...
# 1268207999       15
# 1268208000       21
# 1268208001        3
# 1268208002        3
# 1268208004        1
# Length: 32824, dtype: int64

# %%
counts = data.groupby('timestamp')[['u', 'v']].apply(lambda x: x.shape[0])
plt.plot(counts.index, counts.values)
plt.xlabel('Timestamp')
plt.ylabel('Number of occurrences')
plt.xticks(rotation=45)  # Rotate the x-axis tick labels by 45 degrees
plt.title('Occurrences of shared u,v values at same timestamp')
plt.show()

# %%
data.to_csv(r'tech-as-topology-raw-notdirected.txt', header=None, index=None, sep=' ')

# %%
data
# Out:
#          timestamp     u      v
# 0       1266192000     1      2
# 1       1266474818     3      4
# 2       1266213618     5      6
# 3       1266238515     7      8
# 4       1266192000     9     10
# ...            ...   ...    ...
# 171398  1266204900   160    466
# 171399  1266192000   670  32351
# 171400  1266192000  1794   9116
# 171401  1266192000    53  11520
# 171402  1266268751  9752   6023
#
# [171403 rows x 3 columns]

# %%
# Leb
data_with_no_selfloops = data[data['u'] != data['v']]
data_with_no_selfloops
# Out:
#          timestamp     u      v
# 0       1266192000     1      2
# 1       1266474818     3      4
# 2       1266213618     5      6
# 3       1266238515     7      8
# 4       1266192000     9     10
# ...            ...   ...    ...
# 171398  1266204900   160    466
# 171399  1266192000   670  32351
# 171400  1266192000  1794   9116
# 171401  1266192000    53  11520
# 171402  1266268751  9752   6023
#
# [171403 rows x 3 columns]

# %%
counter = sum(data['u'] == data['v'])
counter
# Out:
# 0

# %% [markdown]
# ## Remove self-loops, make network undirected, and save it

# %%
#g = nx.read_edgelist("diggtoremoveselfloops.txt", create_using=nx.DiGraph(), nodetype = int, data=(('timestamp',int),))
#nx.info(g)
print("Steph: If directed, we have a DiGraph with x nodes and y edges")
# Out:
# Steph: If directed, we have a DiGraph with x nodes and y edges

# %%
g = nx.from_pandas_edgelist(data, source='u', target='v', edge_attr=["timestamp"])
print(nx.info(g))
print("Steph: If not, we have a Graph with x1 nodes and y2 edges, like StrGNN now")
# Out:
# Graph with 34761 nodes and 107720 edges
# Steph: If not, we have a Graph with x1 nodes and y2 edges, like StrGNN now
# <ipython-input-14-608f5827f3bd>:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))

# %%
list(nx.selfloop_edges(g))
# Out:
# []

# %%
len(list(nx.selfloop_edges(g)))
# Out:
# 0

# %%
nx.number_of_selfloops(g)
# Out:
# 0

# %%
# g.remove_edges_from(nx.selfloop_edges(g))

# %%
# Same as the StrGNN paper ✔️
nx.info(g)
# Out:
# <ipython-input-19-2539f43b86d9>:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(g)
# 'Graph with 34761 nodes and 107720 edges'

# %%
df = nx.to_pandas_edgelist(g)
df
# Out:
#         source  target   timestamp
# 0            1       2  1266192000
# 1            1      73  1266192000
# 2            1     257  1266192000
# 3            1     778  1266192000
# 4            1    1867  1266192000
# ...        ...     ...         ...
# 107715   31789   33140  1266192000
# 107716   32200   32201  1266192000
# 107717   32286   34356  1266307197
# 107718   33140   33141  1266192000
# 107719   33229   33393  1266192000
#
# [107720 rows x 3 columns]

# %%
# Rename columns
df.rename(columns = {'source':'u', 'target':'v'}, inplace = True)

# %%
# Changing the position of the columns
df = df[['timestamp', 'u', 'v']]
df
# Out:
#          timestamp      u      v
# 0       1266192000      1      2
# 1       1266192000      1     73
# 2       1266192000      1    257
# 3       1266192000      1    778
# 4       1266192000      1   1867
# ...            ...    ...    ...
# 107715  1266192000  31789  33140
# 107716  1266192000  32200  32201
# 107717  1266307197  32286  34356
# 107718  1266192000  33140  33141
# 107719  1266192000  33229  33393
#
# [107720 rows x 3 columns]

# %%
df.sort_values(by='timestamp', ascending=True, inplace=True)
df
# Out:
#          timestamp     u      v
# 0       1266192000     1      2
# 68464   1266192000   584  12538
# 68465   1266192000   584  25571
# 68466   1266192000   584  26392
# 68467   1266192000   584  24607
# ...            ...   ...    ...
# 73279   1268208001   785   3237
# 35442   1268208001   144   1340
# 54193   1268208002   325   3178
# 38121   1268208002   160  22264
# 102716  1268208004  7105  25235
#
# [107720 rows x 3 columns]

# %%
# Check how many occurances we have in every timestamp
timestamps_grouped = df.groupby('timestamp')[['u', 'v']].apply(lambda x: x.shape[0])
print(timestamps_grouped)
# Out:
# timestamp
# 1266192000    51654
# 1266192001       11
# 1266192002        4
# 1266192003        3
# 1266192004        3
#               ...
# 1268207999       10
# 1268208000       12
# 1268208001        2
# 1268208002        2
# 1268208004        1
# Length: 19827, dtype: int64

# %%
counts = df.groupby('timestamp')[['u', 'v']].apply(lambda x: x.shape[0])
plt.plot(counts.index, counts.values)
plt.xlabel('Timestamp')
plt.ylabel('Number of occurrences')
plt.xticks(rotation=45)  # Rotate the x-axis tick labels by 45 degrees
plt.title('Occurrences of shared u,v values at same timestamp')
plt.show()

# %% [raw]
# df.to_csv(r'tech-as-topology-raw-notdirected.txt', header=None, index=None, sep=' ')

# %% [markdown]
# ### Network topology

# %%
print(nx.info(g))
print(nx.is_directed(g))
# Out:
# Graph with 34761 nodes and 107720 edges
# False
# <ipython-input-26-801602da4655>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))

# %%
A = (g.subgraph(c) for c in nx.connected_components(g))

# %%
list_A = list(A)
list_A

# %%
print("Number of connected components:", len(list_A))
# Out:
# Number of connected components: 1

# %%
N = len(g)
M = g.number_of_edges()
print('Number of nodes:', N)
print('Number of edges:', M)
# Out:
# Number of nodes: 34761
# Number of edges: 107720

# %% [markdown]
# #### Degree

# %%
vk = dict(g.degree())
vk = list(vk.values())
print('Max degree:',max( vk))
print('Min degree:',min( vk))
# Out:
# Max degree: 2760
# Min degree: 1

# %%
md = np.mean(vk)
print('Mean degree:', round(md,3))
# Out:
# Mean degree: 6.198

# %%
def degree_distribution(G):
    vk = dict(G.degree())
    vk = list(vk.values()) # we get only the degree values
    maxk = np.max(vk)
    mink = np.min(min)
    kvalues= np.arange(0,maxk+1) # possible values of k
    Pk = np.zeros(maxk+1) # P(k)
    for k in vk:
        Pk[k] = Pk[k] + 1
    Pk = Pk/sum(Pk) # the sum of the elements of P(k) must to be equal to one
    return kvalues,Pk

# %%
ks, Pk = degree_distribution(g)

# %%
plt.figure()
plt.loglog(ks,Pk,'bo',basex=10,basey=10)
plt.xlabel("k", fontsize=20)
plt.ylabel("P(k)", fontsize=20)
plt.title("Degree distribution", fontsize=20)
plt.grid(True)
#plt.savefig('degree_dist.eps') #save the figure into a file
plt.show(True)
# Out:
# <ipython-input-35-1718d9e68549>:2: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(ks,Pk,'bo',basex=10,basey=10)
# <ipython-input-35-1718d9e68549>:2: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(ks,Pk,'bo',basex=10,basey=10)

# %%
def momment_of_degree_distribution(G,m):
    k,Pk = degree_distribution(G)
    M = sum((k**m)*Pk)
    return M

# %%
k1 = momment_of_degree_distribution(g,1)
print("Mean degree = ", round(np.mean(vk),3))
print("First moment of the degree distribution = ", round(k1,3))
# Out:
# Mean degree =  6.198
# First moment of the degree distribution =  6.198

# %%
k2 = momment_of_degree_distribution(g,2)
print("Second moment of the degree distribution = ", round(k2,3))
# Out:
# Second moment of the degree distribution =  1979.921

# %% [markdown]
# The variance $V(k) = \langle k^2 \rangle - k^2$

# %%
variance = momment_of_degree_distribution(g,2) - momment_of_degree_distribution(g,1)**2
print("Variance of the degree = ", round(variance,3))
# Out:
# Variance of the degree =  1941.509

# %% [markdown]
# #### Clustering and transitivity

# %%
Tran = (nx.transitivity(g)) 
print("Transitivity = ", round(Tran, 7))
# Out:
# Transitivity =  0.0485142

# %%
avc = nx.average_clustering(g)
print("Average clustering:", round(avc, 6))
# Out:
# Average clustering: 0.2891

# %%
vcc = []
for i in g.nodes():
    vcc.append(nx.clustering(g, i))
vcc= np.array(vcc)
print('Clustering of all nodes:', vcc)
# Out:
# Clustering of all nodes: [0.00160428 0.         0.05454545 ... 0.         0.         0.        ]

# %%
plt.figure()
plt.hist(vcc, bins  = 10)
plt.title("Distribution of the clustering coefficient")
plt.ylabel("P(cc)")
plt.xlabel("Clustering coefficient (cc)")
plt.grid(True)
#plt.savefig('clustering.eps') #save the figure into a file
plt.show()

# %% [raw]
# ## Generating random links

# %% [raw]
# linkstream, timestamps, node_set1, node_set2 = read_input("tech-as-topology-raw-notdirected.txt")

# %% [raw]
# linkstream

# %% [raw]
# #timestamps[:10]

# %% [raw]
# node_set1[:10]

# %% [raw]
# node_set2[:10]

# %% [raw]
# add_rdm_links(linkstream, timestamps, node_set1, node_set2, 1, "")

# %% [markdown]
# ## Adding the anomalous links to the raw network and run ML's code
# 🚩 It is important to sort the links before entering them to ML's code

# %%
cols = ["timestamp", "u", "v"]

# %%
df1 = pd.read_csv('tech-as-topology-raw-notdirected.txt', sep=" ",  names=cols)
df1
# Out:
#          timestamp     u      v
# 0       1266192000     1      2
# 1       1266474818     3      4
# 2       1266213618     5      6
# 3       1266238515     7      8
# 4       1266192000     9     10
# ...            ...   ...    ...
# 171398  1266204900   160    466
# 171399  1266192000   670  32351
# 171400  1266192000  1794   9116
# 171401  1266192000    53  11520
# 171402  1266268751  9752   6023
#
# [171403 rows x 3 columns]

# %%
# Find a duplicate rows
duplicateDFRow = df1[df1.duplicated()]
duplicateDFRow
# Out:
#          timestamp    u     v
# 3593    1266307196  515  1385
# 3621    1266192000  289   204
# 3741    1266192000  110   536
# 3942    1266268638  382   951
# 4074    1266307200  387  2421
# ...            ...  ...   ...
# 171376  1266192000  524  1639
# 171378  1266601640  175  4425
# 171387  1266192000   64  1545
# 171392  1266192000  286  2150
# 171395  1266192000  419   418
#
# [15896 rows x 3 columns]

# %%
len(duplicateDFRow)
# Out:
# 15896

# %%
df2 = pd.read_csv('added_links_notdirected.txt', sep=" ",  names=cols)
df2
# Out:
#        timestamp      u      v
# 0     1266419355   8854   1434
# 1     1266275451  19565  20345
# 2     1267685873   5150   6819
# 3     1266214322  11176  32759
# 4     1266203187   7694  23287
# ...          ...    ...    ...
# 8565  1266991533   9342  12933
# 8566  1267825345     83   5582
# 8567  1267358698   9715  30953
# 8568  1267121407    435   4696
# 8569  1266220715   7163   2630
#
# [8570 rows x 3 columns]

# %%
df_final = pd.concat([df1, df2], ignore_index=True)
df_final
# Out:
#          timestamp     u      v
# 0       1266192000     1      2
# 1       1266474818     3      4
# 2       1266213618     5      6
# 3       1266238515     7      8
# 4       1266192000     9     10
# ...            ...   ...    ...
# 179968  1266991533  9342  12933
# 179969  1267825345    83   5582
# 179970  1267358698  9715  30953
# 179971  1267121407   435   4696
# 179972  1266220715  7163   2630
#
# [179973 rows x 3 columns]

# %%
df_final.sort_values(by='timestamp', ascending=True, inplace=True)

# %%
df_final
# Out:
#          timestamp      u      v
# 0       1266192000      1      2
# 120060  1266192000     11   1653
# 120061  1266192000  27691   3712
# 54525   1266192000    424    932
# 120062  1266192000    767   4324
# ...            ...    ...    ...
# 130464  1268208002    160  22264
# 25934   1268208002    304    412
# 62313   1268208002    325   3178
# 176337  1268208004  17367    983
# 144079  1268208004   7105  25235
#
# [179973 rows x 3 columns]

# %%
#df_final.to_csv(r'tech-as-topology-raw-notdirected_5perc_injection.txt', header=None, index=None, sep=' ')

# %% [markdown]
# ## Step 4: Add the `is_fraud` feature

# %%
df1.insert(3, "is_fraud", 0)
df1
# Out:
#          timestamp     u      v  is_fraud
# 0       1266192000     1      2         0
# 1       1266474818     3      4         0
# 2       1266213618     5      6         0
# 3       1266238515     7      8         0
# 4       1266192000     9     10         0
# ...            ...   ...    ...       ...
# 171398  1266204900   160    466         0
# 171399  1266192000   670  32351         0
# 171400  1266192000  1794   9116         0
# 171401  1266192000    53  11520         0
# 171402  1266268751  9752   6023         0
#
# [171403 rows x 4 columns]

# %%
df2.insert(3, "is_fraud", 1)
df2
# Out:
#        timestamp      u      v  is_fraud
# 0     1266419355   8854   1434         1
# 1     1266275451  19565  20345         1
# 2     1267685873   5150   6819         1
# 3     1266214322  11176  32759         1
# 4     1266203187   7694  23287         1
# ...          ...    ...    ...       ...
# 8565  1266991533   9342  12933         1
# 8566  1267825345     83   5582         1
# 8567  1267358698   9715  30953         1
# 8568  1267121407    435   4696         1
# 8569  1266220715   7163   2630         1
#
# [8570 rows x 4 columns]

# %%
df_final_with_labels = pd.concat([df1, df2], ignore_index=True)
df_final_with_labels
# Out:
#          timestamp     u      v  is_fraud
# 0       1266192000     1      2         0
# 1       1266474818     3      4         0
# 2       1266213618     5      6         0
# 3       1266238515     7      8         0
# 4       1266192000     9     10         0
# ...            ...   ...    ...       ...
# 179968  1266991533  9342  12933         1
# 179969  1267825345    83   5582         1
# 179970  1267358698  9715  30953         1
# 179971  1267121407   435   4696         1
# 179972  1266220715  7163   2630         1
#
# [179973 rows x 4 columns]

# %%
df_final_with_labels.sort_values(by='timestamp', ascending=True, inplace=True )
df_final_with_labels
# Out:
#          timestamp      u      v  is_fraud
# 0       1266192000      1      2         0
# 120060  1266192000     11   1653         0
# 120061  1266192000  27691   3712         0
# 54525   1266192000    424    932         0
# 120062  1266192000    767   4324         0
# ...            ...    ...    ...       ...
# 130464  1268208002    160  22264         0
# 25934   1268208002    304    412         0
# 62313   1268208002    325   3178         0
# 176337  1268208004  17367    983         1
# 144079  1268208004   7105  25235         0
#
# [179973 rows x 4 columns]

# %%
df_final_with_labels.reset_index(drop=True, inplace=True)
df_final_with_labels
# Out:
#          timestamp      u      v  is_fraud
# 0       1266192000      1      2         0
# 1       1266192000     11   1653         0
# 2       1266192000  27691   3712         0
# 3       1266192000    424    932         0
# 4       1266192000    767   4324         0
# ...            ...    ...    ...       ...
# 179968  1268208002    160  22264         0
# 179969  1268208002    304    412         0
# 179970  1268208002    325   3178         0
# 179971  1268208004  17367    983         1
# 179972  1268208004   7105  25235         0
#
# [179973 rows x 4 columns]

# %%
df_final_with_labels
# Out:
#          timestamp      u      v  is_fraud
# 0       1266192000      1      2         0
# 1       1266192000     11   1653         0
# 2       1266192000  27691   3712         0
# 3       1266192000    424    932         0
# 4       1266192000    767   4324         0
# ...            ...    ...    ...       ...
# 179968  1268208002    160  22264         0
# 179969  1268208002    304    412         0
# 179970  1268208002    325   3178         0
# 179971  1268208004  17367    983         1
# 179972  1268208004   7105  25235         0
#
# [179973 rows x 4 columns]

# %%
rslt_df = df_final_with_labels.loc[df_final_with_labels['is_fraud'] == 1]
rslt_df
# Out:
#          timestamp      u      v  is_fraud
# 42989   1266192000   3599   3296         1
# 64819   1266192000   4812  31932         1
# 67115   1266192004  29154  15054         1
# 67332   1266192009   1300  15483         1
# 67430   1266192012   1500  12759         1
# ...            ...    ...    ...       ...
# 179868  1268180061  17427  12990         1
# 179871  1268180068  16860   9399         1
# 179874  1268186085   4790  10241         1
# 179881  1268207995   9824   7008         1
# 179971  1268208004  17367    983         1
#
# [8570 rows x 4 columns]

# %% [markdown]
# ## Do the normal ML part

# %% [markdown]
# ### Reading and processing the data

# %% [markdown]
# #### Read in the json file

# %%
# cat uci.txt | python main.py -H 5 -O1 -Ok -K 6
import pandas as pd
import json
import numpy as np
pd.set_option('max_columns', None)

# %%
data = []

with gzip.open('tech-as-topology-raw-notdirected-H1000-O1.json.gz', 'rt', encoding='utf-16') as f:
    for line in f:
        data.append(json.loads(line))

# %%
len(data)
# Out:
# 179973

# %%
print(data[0])
print(data[1])
print(data[2])
print(data[3])
print(data[4])
# Out:
# {'t': 1266192000, 'u': '1', 'v': '2', 'history_type': 'H', 'history_size': 1000, 'bip': False, 'cost': 0.0}
# {'t': 1266192000, 'u': '11', 'v': '1653', 'history_type': 'H', 'history_size': 1000, 'bip': False, 'cost': 0.0}
# {'t': 1266192000, 'u': '27691', 'v': '3712', 'history_type': 'H', 'history_size': 1000, 'bip': False, 'cost': 0.0}
# {'t': 1266192000, 'u': '424', 'v': '932', 'history_type': 'H', 'history_size': 1000, 'bip': False, 'cost': 0.0}
# {'t': 1266192000, 'u': '4324', 'v': '767', 'history_type': 'H', 'history_size': 1000, 'bip': False, 'cost': 0.0}

# %%
print(data[5])
# Out:
# {'t': 1266192000, 'u': '1248', 'v': '20055', 'history_type': 'H', 'history_size': 1000, 'bip': False, 'cost': 0.0}

# %%
print(data[6])
# Out:
# {'t': 1266192000, 'u': '4910', 'v': '64', 'history_type': 'H', 'history_size': 1000, 'bip': False, 'cost': 0.0}

# %% [markdown]
# #### Flatten the internal `O(1)`, `O(k)`, etc... features

# %%
from utilitiesMe import flatten_dict

# %%
# Flattening all rows(
data_flattened = []
for row in data:
    data_flattened.append(flatten_dict(row))

# %%
data_flattened[0]
# Out:
# {'t': 1266192000,
#  'u': '1',
#  'v': '2',
#  'history_type': 'H',
#  'history_size': 1000,
#  'bip': False,
#  'cost': 0.0}

# %% [markdown]
# #### Convert flattened json to dataframe

# %%
df = pd.DataFrame.from_dict(data_flattened, orient='columns')

# %%
df
# Out:
#                  t      u      v history_type  history_size    bip  cost  \
# 0       1266192000      1      2            H          1000  False   0.0
# 1       1266192000     11   1653            H          1000  False   0.0
# 2       1266192000  27691   3712            H          1000  False   0.0
# 3       1266192000    424    932            H          1000  False   0.0
# 4       1266192000   4324    767            H          1000  False   0.0
# ...            ...    ...    ...          ...           ...    ...   ...
# 179968  1268208002    160  22264            H          1000  False   0.0
# 179969  1268208002    304    412            H          1000  False   0.0
# 179970  1268208002   3178    325            H          1000  False   0.0
# 179971  1268208004  17367    983            H          1000  False   0.0
# 179972  1268208004  25235   7105            H          1000  False   0.0
#
#         O1_features.n  O1_features.m  O1_features.degrees.max  \
# 0                 NaN            NaN                      NaN
# 1                 NaN            NaN                      NaN
# 2                 NaN            NaN                      NaN
# 3                 NaN            NaN                      NaN
# 4                 NaN            NaN                      NaN
# ...               ...            ...                      ...
# 179968         1052.0          926.0                     80.0
# 179969         1053.0          926.0                     80.0
# 179970         1053.0          926.0                     80.0
# 179971         1052.0          926.0                     80.0
# 179972         1052.0          926.0                     80.0
#
#         O1_features.degrees.med  O1_features.degrees.tot  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 179968                      1.0                   1852.0
# 179969                      1.0                   1852.0
# 179970                      1.0                   1852.0
# 179971                      1.0                   1852.0
# 179972                      1.0                   1852.0
#
#         O1_features.degrees.nb_1  O1_features.degrees.nb_2  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 179968                     797.0                     128.0
# 179969                     798.0                     129.0
# 179970                     798.0                     129.0
# 179971                     796.0                     130.0
# 179972                     796.0                     130.0
#
#         O1_features.degrees.u  O1_features.degrees.v  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
# ...                       ...                    ...
# 179968                    5.0                    1.0
# 179969                   36.0                    1.0
# 179970                    1.0                   47.0
# 179971                    1.0                    2.0
# 179972                    1.0                    1.0
#
#         O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 179968                              84.0                               1.0
# 179969                              84.0                               1.0
# 179970                              84.0                               1.0
# 179971                              84.0                               1.0
# 179972                              84.0                               1.0
#
#         O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
# ...                                  ...                                ...
# 179968                            2000.0                              769.0
# 179969                            2000.0                              770.0
# 179970                            2000.0                              770.0
# 179971                            2000.0                              768.0
# 179972                            2000.0                              768.0
#
#         O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 179968                              136.0                             5.0
# 179969                              137.0                            36.0
# 179970                              137.0                             1.0
# 179971                              138.0                             1.0
# 179972                              138.0                             1.0
#
#         O1_features.weighted_degrees.v  O1_features.weights.max  \
# 0                                  NaN                      NaN
# 1                                  NaN                      NaN
# 2                                  NaN                      NaN
# 3                                  NaN                      NaN
# 4                                  NaN                      NaN
# ...                                ...                      ...
# 179968                             1.0                      3.0
# 179969                             1.0                      3.0
# 179970                            49.0                      3.0
# 179971                             2.0                      3.0
# 179972                             1.0                      3.0
#
#         O1_features.weights.med  O1_features.weights.tot  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 179968                      1.0                   1000.0
# 179969                      1.0                   1000.0
# 179970                      1.0                   1000.0
# 179971                      1.0                   1000.0
# 179972                      1.0                   1000.0
#
#         O1_features.weights.nb_1  O1_features.weights.nb_2  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 179968                     860.0                      58.0
# 179969                     860.0                      58.0
# 179970                     860.0                      58.0
# 179971                     860.0                      58.0
# 179972                     860.0                      58.0
#
#         O1_features.weight  O1_features.cost
# 0                      NaN               NaN
# 1                      NaN               NaN
# 2                      NaN               NaN
# 3                      NaN               NaN
# 4                      NaN               NaN
# ...                    ...               ...
# 179968                 1.0               0.0
# 179969                 1.0               0.0
# 179970                 1.0               0.0
# 179971                 1.0               0.0
# 179972                 1.0               0.0
#
# [179973 rows x 30 columns]

# %%
df.loc[df["t"] == 1453438800]
# Out:
# Empty DataFrame
# Columns: [t, u, v, history_type, history_size, bip, cost, O1_features.n, O1_features.m, O1_features.degrees.max, O1_features.degrees.med, O1_features.degrees.tot, O1_features.degrees.nb_1, O1_features.degrees.nb_2, O1_features.degrees.u, O1_features.degrees.v, O1_features.weighted_degrees.max, O1_features.weighted_degrees.med, O1_features.weighted_degrees.tot, O1_features.weighted_degrees.nb_1, O1_features.weighted_degrees.nb_2, O1_features.weighted_degrees.u, O1_features.weighted_degrees.v, O1_features.weights.max, O1_features.weights.med, O1_features.weights.tot, O1_features.weights.nb_1, O1_features.weights.nb_2, O1_features.weight, O1_features.cost]
# Index: []

# %%
# Add is_fraud = 1 for the row that is similar to that of df2 (contains anomalous links only)
df.rename(columns={'t': 'timestamp'}, inplace=True)
df
# Out:
#          timestamp      u      v history_type  history_size    bip  cost  \
# 0       1266192000      1      2            H          1000  False   0.0
# 1       1266192000     11   1653            H          1000  False   0.0
# 2       1266192000  27691   3712            H          1000  False   0.0
# 3       1266192000    424    932            H          1000  False   0.0
# 4       1266192000   4324    767            H          1000  False   0.0
# ...            ...    ...    ...          ...           ...    ...   ...
# 179968  1268208002    160  22264            H          1000  False   0.0
# 179969  1268208002    304    412            H          1000  False   0.0
# 179970  1268208002   3178    325            H          1000  False   0.0
# 179971  1268208004  17367    983            H          1000  False   0.0
# 179972  1268208004  25235   7105            H          1000  False   0.0
#
#         O1_features.n  O1_features.m  O1_features.degrees.max  \
# 0                 NaN            NaN                      NaN
# 1                 NaN            NaN                      NaN
# 2                 NaN            NaN                      NaN
# 3                 NaN            NaN                      NaN
# 4                 NaN            NaN                      NaN
# ...               ...            ...                      ...
# 179968         1052.0          926.0                     80.0
# 179969         1053.0          926.0                     80.0
# 179970         1053.0          926.0                     80.0
# 179971         1052.0          926.0                     80.0
# 179972         1052.0          926.0                     80.0
#
#         O1_features.degrees.med  O1_features.degrees.tot  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 179968                      1.0                   1852.0
# 179969                      1.0                   1852.0
# 179970                      1.0                   1852.0
# 179971                      1.0                   1852.0
# 179972                      1.0                   1852.0
#
#         O1_features.degrees.nb_1  O1_features.degrees.nb_2  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 179968                     797.0                     128.0
# 179969                     798.0                     129.0
# 179970                     798.0                     129.0
# 179971                     796.0                     130.0
# 179972                     796.0                     130.0
#
#         O1_features.degrees.u  O1_features.degrees.v  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
# ...                       ...                    ...
# 179968                    5.0                    1.0
# 179969                   36.0                    1.0
# 179970                    1.0                   47.0
# 179971                    1.0                    2.0
# 179972                    1.0                    1.0
#
#         O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 179968                              84.0                               1.0
# 179969                              84.0                               1.0
# 179970                              84.0                               1.0
# 179971                              84.0                               1.0
# 179972                              84.0                               1.0
#
#         O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
# ...                                  ...                                ...
# 179968                            2000.0                              769.0
# 179969                            2000.0                              770.0
# 179970                            2000.0                              770.0
# 179971                            2000.0                              768.0
# 179972                            2000.0                              768.0
#
#         O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 179968                              136.0                             5.0
# 179969                              137.0                            36.0
# 179970                              137.0                             1.0
# 179971                              138.0                             1.0
# 179972                              138.0                             1.0
#
#         O1_features.weighted_degrees.v  O1_features.weights.max  \
# 0                                  NaN                      NaN
# 1                                  NaN                      NaN
# 2                                  NaN                      NaN
# 3                                  NaN                      NaN
# 4                                  NaN                      NaN
# ...                                ...                      ...
# 179968                             1.0                      3.0
# 179969                             1.0                      3.0
# 179970                            49.0                      3.0
# 179971                             2.0                      3.0
# 179972                             1.0                      3.0
#
#         O1_features.weights.med  O1_features.weights.tot  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 179968                      1.0                   1000.0
# 179969                      1.0                   1000.0
# 179970                      1.0                   1000.0
# 179971                      1.0                   1000.0
# 179972                      1.0                   1000.0
#
#         O1_features.weights.nb_1  O1_features.weights.nb_2  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 179968                     860.0                      58.0
# 179969                     860.0                      58.0
# 179970                     860.0                      58.0
# 179971                     860.0                      58.0
# 179972                     860.0                      58.0
#
#         O1_features.weight  O1_features.cost
# 0                      NaN               NaN
# 1                      NaN               NaN
# 2                      NaN               NaN
# 3                      NaN               NaN
# 4                      NaN               NaN
# ...                    ...               ...
# 179968                 1.0               0.0
# 179969                 1.0               0.0
# 179970                 1.0               0.0
# 179971                 1.0               0.0
# 179972                 1.0               0.0
#
# [179973 rows x 30 columns]

# %%
df.describe()
# Out:
#           timestamp  history_size           cost  O1_features.n  \
# count  1.799730e+05      179973.0  179973.000000  178973.000000
# mean   1.266351e+09        1000.0       0.000047    1029.362099
# std    3.605602e+05           0.0       0.000866     296.345305
# min    1.266192e+09        1000.0       0.000000     222.000000
# 25%    1.266192e+09        1000.0       0.000000     761.000000
# 50%    1.266228e+09        1000.0       0.000000    1044.000000
# 75%    1.266307e+09        1000.0       0.000000    1344.000000
# max    1.268208e+09        1000.0       0.031250    1415.000000
#
#        O1_features.m  O1_features.degrees.max  O1_features.degrees.med  \
# count  178973.000000            178973.000000            178973.000000
# mean      952.730429                81.279595                 1.019830
# std        44.452240                59.220297                 0.173067
# min       822.000000                18.000000                 1.000000
# 25%       915.000000                44.000000                 1.000000
# 50%       957.000000                54.000000                 1.000000
# 75%       998.000000               108.000000                 1.000000
# max      1000.000000               433.000000                 3.000000
#
#        O1_features.degrees.tot  O1_features.degrees.nb_1  \
# count            178973.000000             178973.000000
# mean               1905.460857                826.293257
# std                  88.904480                314.904492
# min                1644.000000                 39.000000
# 25%                1830.000000                551.000000
# 50%                1914.000000                794.000000
# 75%                1996.000000               1173.000000
# max                2000.000000               1253.000000
#
#        O1_features.degrees.nb_2  O1_features.degrees.u  O1_features.degrees.v  \
# count             178973.000000          178973.000000          178973.000000
# mean                 100.400697              15.433518              11.951920
# std                   24.038913              38.058773              26.431097
# min                   28.000000               1.000000               1.000000
# 25%                   86.000000               1.000000               1.000000
# 50%                   98.000000               2.000000               2.000000
# 75%                  118.000000              11.000000              10.000000
# max                  189.000000             433.000000             426.000000
#
#        O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# count                     178973.000000                     178973.000000
# mean                          90.247082                          1.023249
# std                           68.020533                          0.186518
# min                           21.000000                          1.000000
# 25%                           45.000000                          1.000000
# 50%                           58.000000                          1.000000
# 75%                          121.000000                          1.000000
# max                          450.000000                          4.000000
#
#        O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# count                          178973.0                      178973.000000
# mean                             2000.0                         811.983729
# std                                 0.0                         321.299530
# min                              2000.0                          36.000000
# 25%                              2000.0                         536.000000
# 50%                              2000.0                         762.000000
# 75%                              2000.0                        1171.000000
# max                              2000.0                        1251.000000
#
#        O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# count                      178973.000000                   178973.000000
# mean                          106.015840                       16.880954
# std                            26.583851                       42.063636
# min                            29.000000                        1.000000
# 25%                            90.000000                        1.000000
# 50%                           102.000000                        2.000000
# 75%                           125.000000                       12.000000
# max                           187.000000                      450.000000
#
#        O1_features.weighted_degrees.v  O1_features.weights.max  \
# count                   178973.000000            178973.000000
# mean                        13.036346                 2.568170
# std                         29.703585                 0.899181
# min                          1.000000                 1.000000
# 25%                          1.000000                 2.000000
# 50%                          2.000000                 2.000000
# 75%                         10.000000                 3.000000
# max                        441.000000                 5.000000
#
#        O1_features.weights.med  O1_features.weights.tot  \
# count                 178973.0                 178973.0
# mean                       1.0                   1000.0
# std                        0.0                      0.0
# min                        1.0                   1000.0
# 25%                        1.0                   1000.0
# 50%                        1.0                   1000.0
# 75%                        1.0                   1000.0
# max                        1.0                   1000.0
#
#        O1_features.weights.nb_1  O1_features.weights.nb_2  O1_features.weight  \
# count             178973.000000             178973.000000       178973.000000
# mean                 908.639275                 41.194677            1.066245
# std                   85.303232                 38.006382            0.268772
# min                  657.000000                  0.000000            1.000000
# 25%                  837.000000                  2.000000            1.000000
# 50%                  916.000000                 41.000000            1.000000
# 75%                  996.000000                 73.000000            1.000000
# max                 1000.000000                159.000000            5.000000
#
#        O1_features.cost
# count     178973.000000
# mean           0.000005
# std            0.000284
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            0.015625

# %% [markdown]
# #### Incorporate the `is_fraud` target variable to the main `df`

# %%
df_final_with_labels
# Out:
#          timestamp      u      v  is_fraud
# 0       1266192000      1      2         0
# 1       1266192000     11   1653         0
# 2       1266192000  27691   3712         0
# 3       1266192000    424    932         0
# 4       1266192000    767   4324         0
# ...            ...    ...    ...       ...
# 179968  1268208002    160  22264         0
# 179969  1268208002    304    412         0
# 179970  1268208002    325   3178         0
# 179971  1268208004  17367    983         1
# 179972  1268208004   7105  25235         0
#
# [179973 rows x 4 columns]

# %%
df_final_with_labels.loc[df_final_with_labels["timestamp"] == 1453438800]
# Out:
# Empty DataFrame
# Columns: [timestamp, u, v, is_fraud]
# Index: []

# %%
df_target_variable = df_final_with_labels[["is_fraud"]]
df_target_variable
# Out:
#         is_fraud
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 179968         0
# 179969         0
# 179970         0
# 179971         1
# 179972         0
#
# [179973 rows x 1 columns]

# %%
df_target_variable["is_fraud"].describe()
# Out:
# count    179973.000000
# mean          0.047618
# std           0.212958
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: is_fraud, dtype: float64

# %%
df_target_variable["is_fraud"].value_counts()
# Out:
# 0    171403
# 1      8570
# Name: is_fraud, dtype: int64

# %% [raw]
# for line in [[int(i) for i in line.strip().split(' ')] for line in open('added_links.txt').readlines()]:
#     print("All line", line)
#     timestamp = line[0]
#     u = line[1]
#     v = line[2]
#     print("timestamp:", timestamp)
#     print("u:", u)
#     print("v:", v)
#     print("")

# %% [raw]
# for index, row in df.iterrows():
#     print(row['timestamp'], row['u'], row['v'])

# %%
len(df)
# Out:
# 179973

# %%
# Join target and feature variables together
df_all = pd.concat([df, df_target_variable], axis = 1)
df_all
# Out:
#          timestamp      u      v history_type  history_size    bip  cost  \
# 0       1266192000      1      2            H          1000  False   0.0
# 1       1266192000     11   1653            H          1000  False   0.0
# 2       1266192000  27691   3712            H          1000  False   0.0
# 3       1266192000    424    932            H          1000  False   0.0
# 4       1266192000   4324    767            H          1000  False   0.0
# ...            ...    ...    ...          ...           ...    ...   ...
# 179968  1268208002    160  22264            H          1000  False   0.0
# 179969  1268208002    304    412            H          1000  False   0.0
# 179970  1268208002   3178    325            H          1000  False   0.0
# 179971  1268208004  17367    983            H          1000  False   0.0
# 179972  1268208004  25235   7105            H          1000  False   0.0
#
#         O1_features.n  O1_features.m  O1_features.degrees.max  \
# 0                 NaN            NaN                      NaN
# 1                 NaN            NaN                      NaN
# 2                 NaN            NaN                      NaN
# 3                 NaN            NaN                      NaN
# 4                 NaN            NaN                      NaN
# ...               ...            ...                      ...
# 179968         1052.0          926.0                     80.0
# 179969         1053.0          926.0                     80.0
# 179970         1053.0          926.0                     80.0
# 179971         1052.0          926.0                     80.0
# 179972         1052.0          926.0                     80.0
#
#         O1_features.degrees.med  O1_features.degrees.tot  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 179968                      1.0                   1852.0
# 179969                      1.0                   1852.0
# 179970                      1.0                   1852.0
# 179971                      1.0                   1852.0
# 179972                      1.0                   1852.0
#
#         O1_features.degrees.nb_1  O1_features.degrees.nb_2  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 179968                     797.0                     128.0
# 179969                     798.0                     129.0
# 179970                     798.0                     129.0
# 179971                     796.0                     130.0
# 179972                     796.0                     130.0
#
#         O1_features.degrees.u  O1_features.degrees.v  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
# ...                       ...                    ...
# 179968                    5.0                    1.0
# 179969                   36.0                    1.0
# 179970                    1.0                   47.0
# 179971                    1.0                    2.0
# 179972                    1.0                    1.0
#
#         O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 179968                              84.0                               1.0
# 179969                              84.0                               1.0
# 179970                              84.0                               1.0
# 179971                              84.0                               1.0
# 179972                              84.0                               1.0
#
#         O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
# ...                                  ...                                ...
# 179968                            2000.0                              769.0
# 179969                            2000.0                              770.0
# 179970                            2000.0                              770.0
# 179971                            2000.0                              768.0
# 179972                            2000.0                              768.0
#
#         O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 179968                              136.0                             5.0
# 179969                              137.0                            36.0
# 179970                              137.0                             1.0
# 179971                              138.0                             1.0
# 179972                              138.0                             1.0
#
#         O1_features.weighted_degrees.v  O1_features.weights.max  \
# 0                                  NaN                      NaN
# 1                                  NaN                      NaN
# 2                                  NaN                      NaN
# 3                                  NaN                      NaN
# 4                                  NaN                      NaN
# ...                                ...                      ...
# 179968                             1.0                      3.0
# 179969                             1.0                      3.0
# 179970                            49.0                      3.0
# 179971                             2.0                      3.0
# 179972                             1.0                      3.0
#
#         O1_features.weights.med  O1_features.weights.tot  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 179968                      1.0                   1000.0
# 179969                      1.0                   1000.0
# 179970                      1.0                   1000.0
# 179971                      1.0                   1000.0
# 179972                      1.0                   1000.0
#
#         O1_features.weights.nb_1  O1_features.weights.nb_2  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 179968                     860.0                      58.0
# 179969                     860.0                      58.0
# 179970                     860.0                      58.0
# 179971                     860.0                      58.0
# 179972                     860.0                      58.0
#
#         O1_features.weight  O1_features.cost  is_fraud
# 0                      NaN               NaN         0
# 1                      NaN               NaN         0
# 2                      NaN               NaN         0
# 3                      NaN               NaN         0
# 4                      NaN               NaN         0
# ...                    ...               ...       ...
# 179968                 1.0               0.0         0
# 179969                 1.0               0.0         0
# 179970                 1.0               0.0         0
# 179971                 1.0               0.0         1
# 179972                 1.0               0.0         0
#
# [179973 rows x 31 columns]

# %%
rslt_df = df_all.loc[df_all['is_fraud'] == 1]
rslt_df
# Out:
#          timestamp      u      v history_type  history_size    bip  cost  \
# 42989   1266192000   3296   3599            H          1000  False   0.0
# 64819   1266192000  31932   4812            H          1000  False   0.0
# 67115   1266192004  15054  29154            H          1000  False   0.0
# 67332   1266192009   1300  15483            H          1000  False   0.0
# 67430   1266192012  12759   1500            H          1000  False   0.0
# ...            ...    ...    ...          ...           ...    ...   ...
# 179868  1268180061  12990  17427            H          1000  False   0.0
# 179871  1268180068  16860   9399            H          1000  False   0.0
# 179874  1268186085  10241   4790            H          1000  False   0.0
# 179881  1268207995   7008   9824            H          1000  False   0.0
# 179971  1268208004  17367    983            H          1000  False   0.0
#
#         O1_features.n  O1_features.m  O1_features.degrees.max  \
# 42989          1371.0          999.0                     52.0
# 64819          1378.0          997.0                     51.0
# 67115          1258.0          993.0                     53.0
# 67332          1021.0          970.0                     53.0
# 67430           925.0          955.0                     51.0
# ...               ...            ...                      ...
# 179868         1047.0          924.0                     80.0
# 179871         1047.0          924.0                     80.0
# 179874         1047.0          924.0                     80.0
# 179881         1044.0          924.0                     80.0
# 179971         1052.0          926.0                     80.0
#
#         O1_features.degrees.med  O1_features.degrees.tot  \
# 42989                       1.0                   1998.0
# 64819                       1.0                   1994.0
# 67115                       1.0                   1986.0
# 67332                       1.0                   1940.0
# 67430                       1.0                   1910.0
# ...                         ...                      ...
# 179868                      1.0                   1848.0
# 179871                      1.0                   1848.0
# 179874                      1.0                   1848.0
# 179881                      1.0                   1848.0
# 179971                      1.0                   1852.0
#
#         O1_features.degrees.nb_1  O1_features.degrees.nb_2  \
# 42989                     1206.0                      96.0
# 64819                     1217.0                      93.0
# 67115                     1096.0                      81.0
# 67332                      847.0                      79.0
# 67430                      756.0                      64.0
# ...                          ...                       ...
# 179868                     798.0                     126.0
# 179871                     799.0                     121.0
# 179874                     798.0                     122.0
# 179881                     793.0                     123.0
# 179971                     796.0                     130.0
#
#         O1_features.degrees.u  O1_features.degrees.v  \
# 42989                     1.0                    1.0
# 64819                     1.0                    1.0
# 67115                     1.0                    1.0
# 67332                     1.0                    1.0
# 67430                     1.0                    1.0
# ...                       ...                    ...
# 179868                    1.0                    1.0
# 179871                    3.0                    1.0
# 179874                    1.0                    1.0
# 179881                    1.0                    3.0
# 179971                    1.0                    2.0
#
#         O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# 42989                               52.0                               1.0
# 64819                               51.0                               1.0
# 67115                               55.0                               1.0
# 67332                               56.0                               1.0
# 67430                               54.0                               1.0
# ...                                  ...                               ...
# 179868                              84.0                               1.0
# 179871                              84.0                               1.0
# 179874                              84.0                               1.0
# 179881                              84.0                               1.0
# 179971                              84.0                               1.0
#
#         O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# 42989                             2000.0                             1205.0
# 64819                             2000.0                             1214.0
# 67115                             2000.0                             1093.0
# 67332                             2000.0                              844.0
# 67430                             2000.0                              753.0
# ...                                  ...                                ...
# 179868                            2000.0                              770.0
# 179871                            2000.0                              771.0
# 179874                            2000.0                              770.0
# 179881                            2000.0                              765.0
# 179971                            2000.0                              768.0
#
#         O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# 42989                                97.0                             1.0
# 64819                                95.0                             1.0
# 67115                                84.0                             1.0
# 67332                                81.0                             1.0
# 67430                                66.0                             1.0
# ...                                   ...                             ...
# 179868                              131.0                             1.0
# 179871                              128.0                             4.0
# 179874                              129.0                             1.0
# 179881                              130.0                             1.0
# 179971                              138.0                             1.0
#
#         O1_features.weighted_degrees.v  O1_features.weights.max  \
# 42989                              1.0                      2.0
# 64819                              1.0                      2.0
# 67115                              1.0                      2.0
# 67332                              1.0                      2.0
# 67430                              1.0                      3.0
# ...                                ...                      ...
# 179868                             1.0                      3.0
# 179871                             1.0                      3.0
# 179874                             1.0                      3.0
# 179881                             3.0                      3.0
# 179971                             2.0                      3.0
#
#         O1_features.weights.med  O1_features.weights.tot  \
# 42989                       1.0                   1000.0
# 64819                       1.0                   1000.0
# 67115                       1.0                   1000.0
# 67332                       1.0                   1000.0
# 67430                       1.0                   1000.0
# ...                         ...                      ...
# 179868                      1.0                   1000.0
# 179871                      1.0                   1000.0
# 179874                      1.0                   1000.0
# 179881                      1.0                   1000.0
# 179971                      1.0                   1000.0
#
#         O1_features.weights.nb_1  O1_features.weights.nb_2  \
# 42989                      998.0                       1.0
# 64819                      994.0                       3.0
# 67115                      986.0                       7.0
# 67332                      940.0                      30.0
# 67430                      911.0                      43.0
# ...                          ...                       ...
# 179868                     856.0                      60.0
# 179871                     856.0                      60.0
# 179874                     856.0                      60.0
# 179881                     856.0                      60.0
# 179971                     860.0                      58.0
#
#         O1_features.weight  O1_features.cost  is_fraud
# 42989                  1.0               0.0         1
# 64819                  1.0               0.0         1
# 67115                  1.0               0.0         1
# 67332                  1.0               0.0         1
# 67430                  1.0               0.0         1
# ...                    ...               ...       ...
# 179868                 1.0               0.0         1
# 179871                 1.0               0.0         1
# 179874                 1.0               0.0         1
# 179881                 1.0               0.0         1
# 179971                 1.0               0.0         1
#
# [8570 rows x 31 columns]

# %%
df_all.head(10)
# Out:
#     timestamp      u      v history_type  history_size    bip  cost  \
# 0  1266192000      1      2            H          1000  False   0.0
# 1  1266192000     11   1653            H          1000  False   0.0
# 2  1266192000  27691   3712            H          1000  False   0.0
# 3  1266192000    424    932            H          1000  False   0.0
# 4  1266192000   4324    767            H          1000  False   0.0
# 5  1266192000   1248  20055            H          1000  False   0.0
# 6  1266192000   4910     64            H          1000  False   0.0
# 7  1266192000  12347    584            H          1000  False   0.0
# 8  1266192000  20054    370            H          1000  False   0.0
# 9  1266192000  21054    520            H          1000  False   0.0
#
#    O1_features.n  O1_features.m  O1_features.degrees.max  \
# 0            NaN            NaN                      NaN
# 1            NaN            NaN                      NaN
# 2            NaN            NaN                      NaN
# 3            NaN            NaN                      NaN
# 4            NaN            NaN                      NaN
# 5            NaN            NaN                      NaN
# 6            NaN            NaN                      NaN
# 7            NaN            NaN                      NaN
# 8            NaN            NaN                      NaN
# 9            NaN            NaN                      NaN
#
#    O1_features.degrees.med  O1_features.degrees.tot  O1_features.degrees.nb_1  \
# 0                      NaN                      NaN                       NaN
# 1                      NaN                      NaN                       NaN
# 2                      NaN                      NaN                       NaN
# 3                      NaN                      NaN                       NaN
# 4                      NaN                      NaN                       NaN
# 5                      NaN                      NaN                       NaN
# 6                      NaN                      NaN                       NaN
# 7                      NaN                      NaN                       NaN
# 8                      NaN                      NaN                       NaN
# 9                      NaN                      NaN                       NaN
#
#    O1_features.degrees.nb_2  O1_features.degrees.u  O1_features.degrees.v  \
# 0                       NaN                    NaN                    NaN
# 1                       NaN                    NaN                    NaN
# 2                       NaN                    NaN                    NaN
# 3                       NaN                    NaN                    NaN
# 4                       NaN                    NaN                    NaN
# 5                       NaN                    NaN                    NaN
# 6                       NaN                    NaN                    NaN
# 7                       NaN                    NaN                    NaN
# 8                       NaN                    NaN                    NaN
# 9                       NaN                    NaN                    NaN
#
#    O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# 5                               NaN                               NaN
# 6                               NaN                               NaN
# 7                               NaN                               NaN
# 8                               NaN                               NaN
# 9                               NaN                               NaN
#
#    O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
# 5                               NaN                                NaN
# 6                               NaN                                NaN
# 7                               NaN                                NaN
# 8                               NaN                                NaN
# 9                               NaN                                NaN
#
#    O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
# 5                                NaN                             NaN
# 6                                NaN                             NaN
# 7                                NaN                             NaN
# 8                                NaN                             NaN
# 9                                NaN                             NaN
#
#    O1_features.weighted_degrees.v  O1_features.weights.max  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
# 2                             NaN                      NaN
# 3                             NaN                      NaN
# 4                             NaN                      NaN
# 5                             NaN                      NaN
# 6                             NaN                      NaN
# 7                             NaN                      NaN
# 8                             NaN                      NaN
# 9                             NaN                      NaN
#
#    O1_features.weights.med  O1_features.weights.tot  O1_features.weights.nb_1  \
# 0                      NaN                      NaN                       NaN
# 1                      NaN                      NaN                       NaN
# 2                      NaN                      NaN                       NaN
# 3                      NaN                      NaN                       NaN
# 4                      NaN                      NaN                       NaN
# 5                      NaN                      NaN                       NaN
# 6                      NaN                      NaN                       NaN
# 7                      NaN                      NaN                       NaN
# 8                      NaN                      NaN                       NaN
# 9                      NaN                      NaN                       NaN
#
#    O1_features.weights.nb_2  O1_features.weight  O1_features.cost  is_fraud
# 0                       NaN                 NaN               NaN         0
# 1                       NaN                 NaN               NaN         0
# 2                       NaN                 NaN               NaN         0
# 3                       NaN                 NaN               NaN         0
# 4                       NaN                 NaN               NaN         0
# 5                       NaN                 NaN               NaN         0
# 6                       NaN                 NaN               NaN         0
# 7                       NaN                 NaN               NaN         0
# 8                       NaN                 NaN               NaN         0
# 9                       NaN                 NaN               NaN         0

# %%
# Assuming your DataFrame is named 'df'
# Create a new DataFrame to preserve rows with NaN
nan_df = pd.DataFrame(columns=df_all.columns)

# Remove rows with NaN from 'df' and append them to 'nan_df'
nan_rows = df_all[df_all.isnull().any(axis=1)]
df_all = df_all.dropna()
nan_df = nan_df.append(nan_rows)

# Display the updated 'df' and 'nan_df'
print("Updated DataFrame without NaN:")
df_all
# Out:
# Updated DataFrame without NaN:
#          timestamp      u      v history_type  history_size    bip  cost  \
# 1000    1266192000  30373    721            H          1000  False   0.0
# 1001    1266192000     11   8045            H          1000  False   0.0
# 1002    1266192000  28701      9            H          1000  False   0.0
# 1003    1266192000   2988    524            H          1000  False   0.0
# 1004    1266192000   1361  30374            H          1000  False   0.0
# ...            ...    ...    ...          ...           ...    ...   ...
# 179968  1268208002    160  22264            H          1000  False   0.0
# 179969  1268208002    304    412            H          1000  False   0.0
# 179970  1268208002   3178    325            H          1000  False   0.0
# 179971  1268208004  17367    983            H          1000  False   0.0
# 179972  1268208004  25235   7105            H          1000  False   0.0
#
#         O1_features.n  O1_features.m  O1_features.degrees.max  \
# 1000           1334.0          999.0                     50.0
# 1001           1333.0          999.0                     50.0
# 1002           1332.0          999.0                     50.0
# 1003           1331.0          999.0                     50.0
# 1004           1331.0          999.0                     50.0
# ...               ...            ...                      ...
# 179968         1052.0          926.0                     80.0
# 179969         1053.0          926.0                     80.0
# 179970         1053.0          926.0                     80.0
# 179971         1052.0          926.0                     80.0
# 179972         1052.0          926.0                     80.0
#
#         O1_features.degrees.med  O1_features.degrees.tot  \
# 1000                        1.0                   1998.0
# 1001                        1.0                   1998.0
# 1002                        1.0                   1998.0
# 1003                        1.0                   1998.0
# 1004                        1.0                   1998.0
# ...                         ...                      ...
# 179968                      1.0                   1852.0
# 179969                      1.0                   1852.0
# 179970                      1.0                   1852.0
# 179971                      1.0                   1852.0
# 179972                      1.0                   1852.0
#
#         O1_features.degrees.nb_1  O1_features.degrees.nb_2  \
# 1000                      1165.0                      93.0
# 1001                      1163.0                      94.0
# 1002                      1162.0                      94.0
# 1003                      1160.0                      95.0
# 1004                      1160.0                      95.0
# ...                          ...                       ...
# 179968                     797.0                     128.0
# 179969                     798.0                     129.0
# 179970                     798.0                     129.0
# 179971                     796.0                     130.0
# 179972                     796.0                     130.0
#
#         O1_features.degrees.u  O1_features.degrees.v  \
# 1000                      1.0                    1.0
# 1001                     50.0                    2.0
# 1002                      1.0                   24.0
# 1003                      2.0                   18.0
# 1004                      1.0                    1.0
# ...                       ...                    ...
# 179968                    5.0                    1.0
# 179969                   36.0                    1.0
# 179970                    1.0                   47.0
# 179971                    1.0                    2.0
# 179972                    1.0                    1.0
#
#         O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# 1000                                50.0                               1.0
# 1001                                50.0                               1.0
# 1002                                50.0                               1.0
# 1003                                50.0                               1.0
# 1004                                50.0                               1.0
# ...                                  ...                               ...
# 179968                              84.0                               1.0
# 179969                              84.0                               1.0
# 179970                              84.0                               1.0
# 179971                              84.0                               1.0
# 179972                              84.0                               1.0
#
#         O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# 1000                              2000.0                             1164.0
# 1001                              2000.0                             1162.0
# 1002                              2000.0                             1161.0
# 1003                              2000.0                             1159.0
# 1004                              2000.0                             1159.0
# ...                                  ...                                ...
# 179968                            2000.0                              769.0
# 179969                            2000.0                              770.0
# 179970                            2000.0                              770.0
# 179971                            2000.0                              768.0
# 179972                            2000.0                              768.0
#
#         O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# 1000                                 94.0                             1.0
# 1001                                 95.0                            50.0
# 1002                                 95.0                             1.0
# 1003                                 96.0                             2.0
# 1004                                 96.0                             1.0
# ...                                   ...                             ...
# 179968                              136.0                             5.0
# 179969                              137.0                            36.0
# 179970                              137.0                             1.0
# 179971                              138.0                             1.0
# 179972                              138.0                             1.0
#
#         O1_features.weighted_degrees.v  O1_features.weights.max  \
# 1000                               1.0                      2.0
# 1001                               2.0                      2.0
# 1002                              24.0                      2.0
# 1003                              18.0                      2.0
# 1004                               1.0                      2.0
# ...                                ...                      ...
# 179968                             1.0                      3.0
# 179969                             1.0                      3.0
# 179970                            49.0                      3.0
# 179971                             2.0                      3.0
# 179972                             1.0                      3.0
#
#         O1_features.weights.med  O1_features.weights.tot  \
# 1000                        1.0                   1000.0
# 1001                        1.0                   1000.0
# 1002                        1.0                   1000.0
# 1003                        1.0                   1000.0
# 1004                        1.0                   1000.0
# ...                         ...                      ...
# 179968                      1.0                   1000.0
# 179969                      1.0                   1000.0
# 179970                      1.0                   1000.0
# 179971                      1.0                   1000.0
# 179972                      1.0                   1000.0
#
#         O1_features.weights.nb_1  O1_features.weights.nb_2  \
# 1000                       998.0                       1.0
# 1001                       998.0                       1.0
# 1002                       998.0                       1.0
# 1003                       998.0                       1.0
# 1004                       998.0                       1.0
# ...                          ...                       ...
# 179968                     860.0                      58.0
# 179969                     860.0                      58.0
# 179970                     860.0                      58.0
# 179971                     860.0                      58.0
# 179972                     860.0                      58.0
#
#         O1_features.weight  O1_features.cost  is_fraud
# 1000                   1.0               0.0         0
# 1001                   1.0               0.0         0
# 1002                   1.0               0.0         0
# 1003                   1.0               0.0         0
# 1004                   1.0               0.0         0
# ...                    ...               ...       ...
# 179968                 1.0               0.0         0
# 179969                 1.0               0.0         0
# 179970                 1.0               0.0         0
# 179971                 1.0               0.0         1
# 179972                 1.0               0.0         0
#
# [178973 rows x 31 columns]

# %%
df_all.describe()
# Out:
#           timestamp  history_size           cost  O1_features.n  \
# count  1.789730e+05      178973.0  178973.000000  178973.000000
# mean   1.266352e+09        1000.0       0.000048    1029.362099
# std    3.613698e+05           0.0       0.000869     296.345305
# min    1.266192e+09        1000.0       0.000000     222.000000
# 25%    1.266192e+09        1000.0       0.000000     761.000000
# 50%    1.266229e+09        1000.0       0.000000    1044.000000
# 75%    1.266307e+09        1000.0       0.000000    1344.000000
# max    1.268208e+09        1000.0       0.031250    1415.000000
#
#        O1_features.m  O1_features.degrees.max  O1_features.degrees.med  \
# count  178973.000000            178973.000000            178973.000000
# mean      952.730429                81.279595                 1.019830
# std        44.452240                59.220297                 0.173067
# min       822.000000                18.000000                 1.000000
# 25%       915.000000                44.000000                 1.000000
# 50%       957.000000                54.000000                 1.000000
# 75%       998.000000               108.000000                 1.000000
# max      1000.000000               433.000000                 3.000000
#
#        O1_features.degrees.tot  O1_features.degrees.nb_1  \
# count            178973.000000             178973.000000
# mean               1905.460857                826.293257
# std                  88.904480                314.904492
# min                1644.000000                 39.000000
# 25%                1830.000000                551.000000
# 50%                1914.000000                794.000000
# 75%                1996.000000               1173.000000
# max                2000.000000               1253.000000
#
#        O1_features.degrees.nb_2  O1_features.degrees.u  O1_features.degrees.v  \
# count             178973.000000          178973.000000          178973.000000
# mean                 100.400697              15.433518              11.951920
# std                   24.038913              38.058773              26.431097
# min                   28.000000               1.000000               1.000000
# 25%                   86.000000               1.000000               1.000000
# 50%                   98.000000               2.000000               2.000000
# 75%                  118.000000              11.000000              10.000000
# max                  189.000000             433.000000             426.000000
#
#        O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# count                     178973.000000                     178973.000000
# mean                          90.247082                          1.023249
# std                           68.020533                          0.186518
# min                           21.000000                          1.000000
# 25%                           45.000000                          1.000000
# 50%                           58.000000                          1.000000
# 75%                          121.000000                          1.000000
# max                          450.000000                          4.000000
#
#        O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# count                          178973.0                      178973.000000
# mean                             2000.0                         811.983729
# std                                 0.0                         321.299530
# min                              2000.0                          36.000000
# 25%                              2000.0                         536.000000
# 50%                              2000.0                         762.000000
# 75%                              2000.0                        1171.000000
# max                              2000.0                        1251.000000
#
#        O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# count                      178973.000000                   178973.000000
# mean                          106.015840                       16.880954
# std                            26.583851                       42.063636
# min                            29.000000                        1.000000
# 25%                            90.000000                        1.000000
# 50%                           102.000000                        2.000000
# 75%                           125.000000                       12.000000
# max                           187.000000                      450.000000
#
#        O1_features.weighted_degrees.v  O1_features.weights.max  \
# count                   178973.000000            178973.000000
# mean                        13.036346                 2.568170
# std                         29.703585                 0.899181
# min                          1.000000                 1.000000
# 25%                          1.000000                 2.000000
# 50%                          2.000000                 2.000000
# 75%                         10.000000                 3.000000
# max                        441.000000                 5.000000
#
#        O1_features.weights.med  O1_features.weights.tot  \
# count                 178973.0                 178973.0
# mean                       1.0                   1000.0
# std                        0.0                      0.0
# min                        1.0                   1000.0
# 25%                        1.0                   1000.0
# 50%                        1.0                   1000.0
# 75%                        1.0                   1000.0
# max                        1.0                   1000.0
#
#        O1_features.weights.nb_1  O1_features.weights.nb_2  O1_features.weight  \
# count             178973.000000             178973.000000       178973.000000
# mean                 908.639275                 41.194677            1.066245
# std                   85.303232                 38.006382            0.268772
# min                  657.000000                  0.000000            1.000000
# 25%                  837.000000                  2.000000            1.000000
# 50%                  916.000000                 41.000000            1.000000
# 75%                  996.000000                 73.000000            1.000000
# max                 1000.000000                159.000000            5.000000
#
#        O1_features.cost       is_fraud
# count     178973.000000  178973.000000
# mean           0.000005       0.047884
# std            0.000284       0.213522
# min            0.000000       0.000000
# 25%            0.000000       0.000000
# 50%            0.000000       0.000000
# 75%            0.000000       0.000000
# max            0.015625       1.000000

# %%
df_features = df_all.drop(["timestamp", "u", "v", 
                           "history_type", 
                           "bip", 
                           "cost", 
                           "O1_features.cost", 
                           "history_size"], axis="columns")
df_features
# Out:
#         O1_features.n  O1_features.m  O1_features.degrees.max  \
# 1000           1334.0          999.0                     50.0
# 1001           1333.0          999.0                     50.0
# 1002           1332.0          999.0                     50.0
# 1003           1331.0          999.0                     50.0
# 1004           1331.0          999.0                     50.0
# ...               ...            ...                      ...
# 179968         1052.0          926.0                     80.0
# 179969         1053.0          926.0                     80.0
# 179970         1053.0          926.0                     80.0
# 179971         1052.0          926.0                     80.0
# 179972         1052.0          926.0                     80.0
#
#         O1_features.degrees.med  O1_features.degrees.tot  \
# 1000                        1.0                   1998.0
# 1001                        1.0                   1998.0
# 1002                        1.0                   1998.0
# 1003                        1.0                   1998.0
# 1004                        1.0                   1998.0
# ...                         ...                      ...
# 179968                      1.0                   1852.0
# 179969                      1.0                   1852.0
# 179970                      1.0                   1852.0
# 179971                      1.0                   1852.0
# 179972                      1.0                   1852.0
#
#         O1_features.degrees.nb_1  O1_features.degrees.nb_2  \
# 1000                      1165.0                      93.0
# 1001                      1163.0                      94.0
# 1002                      1162.0                      94.0
# 1003                      1160.0                      95.0
# 1004                      1160.0                      95.0
# ...                          ...                       ...
# 179968                     797.0                     128.0
# 179969                     798.0                     129.0
# 179970                     798.0                     129.0
# 179971                     796.0                     130.0
# 179972                     796.0                     130.0
#
#         O1_features.degrees.u  O1_features.degrees.v  \
# 1000                      1.0                    1.0
# 1001                     50.0                    2.0
# 1002                      1.0                   24.0
# 1003                      2.0                   18.0
# 1004                      1.0                    1.0
# ...                       ...                    ...
# 179968                    5.0                    1.0
# 179969                   36.0                    1.0
# 179970                    1.0                   47.0
# 179971                    1.0                    2.0
# 179972                    1.0                    1.0
#
#         O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# 1000                                50.0                               1.0
# 1001                                50.0                               1.0
# 1002                                50.0                               1.0
# 1003                                50.0                               1.0
# 1004                                50.0                               1.0
# ...                                  ...                               ...
# 179968                              84.0                               1.0
# 179969                              84.0                               1.0
# 179970                              84.0                               1.0
# 179971                              84.0                               1.0
# 179972                              84.0                               1.0
#
#         O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# 1000                              2000.0                             1164.0
# 1001                              2000.0                             1162.0
# 1002                              2000.0                             1161.0
# 1003                              2000.0                             1159.0
# 1004                              2000.0                             1159.0
# ...                                  ...                                ...
# 179968                            2000.0                              769.0
# 179969                            2000.0                              770.0
# 179970                            2000.0                              770.0
# 179971                            2000.0                              768.0
# 179972                            2000.0                              768.0
#
#         O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# 1000                                 94.0                             1.0
# 1001                                 95.0                            50.0
# 1002                                 95.0                             1.0
# 1003                                 96.0                             2.0
# 1004                                 96.0                             1.0
# ...                                   ...                             ...
# 179968                              136.0                             5.0
# 179969                              137.0                            36.0
# 179970                              137.0                             1.0
# 179971                              138.0                             1.0
# 179972                              138.0                             1.0
#
#         O1_features.weighted_degrees.v  O1_features.weights.max  \
# 1000                               1.0                      2.0
# 1001                               2.0                      2.0
# 1002                              24.0                      2.0
# 1003                              18.0                      2.0
# 1004                               1.0                      2.0
# ...                                ...                      ...
# 179968                             1.0                      3.0
# 179969                             1.0                      3.0
# 179970                            49.0                      3.0
# 179971                             2.0                      3.0
# 179972                             1.0                      3.0
#
#         O1_features.weights.med  O1_features.weights.tot  \
# 1000                        1.0                   1000.0
# 1001                        1.0                   1000.0
# 1002                        1.0                   1000.0
# 1003                        1.0                   1000.0
# 1004                        1.0                   1000.0
# ...                         ...                      ...
# 179968                      1.0                   1000.0
# 179969                      1.0                   1000.0
# 179970                      1.0                   1000.0
# 179971                      1.0                   1000.0
# 179972                      1.0                   1000.0
#
#         O1_features.weights.nb_1  O1_features.weights.nb_2  \
# 1000                       998.0                       1.0
# 1001                       998.0                       1.0
# 1002                       998.0                       1.0
# 1003                       998.0                       1.0
# 1004                       998.0                       1.0
# ...                          ...                       ...
# 179968                     860.0                      58.0
# 179969                     860.0                      58.0
# 179970                     860.0                      58.0
# 179971                     860.0                      58.0
# 179972                     860.0                      58.0
#
#         O1_features.weight  is_fraud
# 1000                   1.0         0
# 1001                   1.0         0
# 1002                   1.0         0
# 1003                   1.0         0
# 1004                   1.0         0
# ...                    ...       ...
# 179968                 1.0         0
# 179969                 1.0         0
# 179970                 1.0         0
# 179971                 1.0         1
# 179972                 1.0         0
#
# [178973 rows x 23 columns]

# %%
df_target = df_all["is_fraud"]
df_target
# Out:
# 1000      0
# 1001      0
# 1002      0
# 1003      0
# 1004      0
#          ..
# 179968    0
# 179969    0
# 179970    0
# 179971    1
# 179972    0
# Name: is_fraud, Length: 178973, dtype: int64

# %% [markdown]
# ## Machine learning with undersampling

# %% [markdown]
# ### Undersampling

# %%
# Dataset info
# df_features.info()

# %%
df_features["is_fraud"].value_counts()
# Out:
# 0    170403
# 1      8570
# Name: is_fraud, dtype: int64

# %%
# Separating the data for analysis (they will be Series)
nonanomalous = df_features[df_features.is_fraud == 0]
anomalous = df_features[df_features.is_fraud == 1]

# %%
print(len(nonanomalous))
print(len(anomalous))
# Out:
# 170403
# 8570

# %%
print(nonanomalous.shape)
print(anomalous.shape)
# Out:
# (170403, 23)
# (8570, 23)

# %%
# Compare the values for both classes
# We can see differences between nonanomalous and anomalous based on the feautres,
# --> these differences are very important for us as this is how the ML models can detect anomalous links.
df_features.groupby("is_fraud").mean()
# Out:
#           O1_features.n  O1_features.m  O1_features.degrees.max  \
# is_fraud
# 0           1036.356050     954.814980                81.797738
# 1            890.296733     911.281914                70.977013
#
#           O1_features.degrees.med  O1_features.degrees.tot  \
# is_fraud
# 0                        1.020446              1909.629960
# 1                        1.007585              1822.563827
#
#           O1_features.degrees.nb_1  O1_features.degrees.nb_2  \
# is_fraud
# 0                       834.627747                100.368127
# 1                       660.573046                101.048308
#
#           O1_features.degrees.u  O1_features.degrees.v  \
# is_fraud
# 0                     16.151840              12.495590
# 1                      1.150642               1.141774
#
#           O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# is_fraud
# 0                                90.493031                          1.024020
# 1                                85.356709                          1.007935
#
#           O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# is_fraud
# 0                                   2000.0                         821.042499
# 1                                   2000.0                         631.862194
#
#           O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# is_fraud
# 0                                105.662582                       17.671109
# 1                                113.039907                        1.169778
#
#           O1_features.weighted_degrees.v  O1_features.weights.max  \
# is_fraud
# 0                              13.633868                 2.524017
# 1                               1.155426                 3.446091
#
#           O1_features.weights.med  O1_features.weights.tot  \
# is_fraud
# 0                             1.0                   1000.0
# 1                             1.0                   1000.0
#
#           O1_features.weights.nb_1  O1_features.weights.nb_2  \
# is_fraud
# 0                       912.587108                 39.528846
# 1                       830.141890                 74.317503
#
#           O1_features.weight
# is_fraud
# 0                   1.069570
# 1                   1.000117

# %%
# Sampling
nonanomalous_sample = nonanomalous.sample(n = 8570, random_state=12)

# %%
# Concatenating
# Author: Axis = 0 means all the rows of `anomalous` will be added below `nonanomalous_sample`.
new_dataset = pd.concat([nonanomalous_sample, anomalous], axis=0)

# %%
new_dataset
# Out:
#         O1_features.n  O1_features.m  O1_features.degrees.max  \
# 168926         1077.0          919.0                     49.0
# 92787           688.0          915.0                     32.0
# 119998          701.0          886.0                    233.0
# 5204           1366.0          998.0                     40.0
# 36638          1369.0          999.0                     41.0
# ...               ...            ...                      ...
# 179868         1047.0          924.0                     80.0
# 179871         1047.0          924.0                     80.0
# 179874         1047.0          924.0                     80.0
# 179881         1044.0          924.0                     80.0
# 179971         1052.0          926.0                     80.0
#
#         O1_features.degrees.med  O1_features.degrees.tot  \
# 168926                      1.0                   1838.0
# 92787                       1.0                   1830.0
# 119998                      1.0                   1772.0
# 5204                        1.0                   1996.0
# 36638                       1.0                   1998.0
# ...                         ...                      ...
# 179868                      1.0                   1848.0
# 179871                      1.0                   1848.0
# 179874                      1.0                   1848.0
# 179881                      1.0                   1848.0
# 179971                      1.0                   1852.0
#
#         O1_features.degrees.nb_1  O1_features.degrees.nb_2  \
# 168926                     811.0                     125.0
# 92787                      464.0                      78.0
# 119998                     487.0                     127.0
# 5204                      1210.0                      76.0
# 36638                     1191.0                     103.0
# ...                          ...                       ...
# 179868                     798.0                     126.0
# 179871                     799.0                     121.0
# 179874                     798.0                     122.0
# 179881                     793.0                     123.0
# 179971                     796.0                     130.0
#
#         O1_features.degrees.u  O1_features.degrees.v  \
# 168926                    1.0                    5.0
# 92787                     8.0                    9.0
# 119998                  233.0                    1.0
# 5204                      1.0                    1.0
# 36638                    31.0                    1.0
# ...                       ...                    ...
# 179868                    1.0                    1.0
# 179871                    3.0                    1.0
# 179874                    1.0                    1.0
# 179881                    1.0                    3.0
# 179971                    1.0                    2.0
#
#         O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# 168926                              58.0                               1.0
# 92787                               41.0                               1.0
# 119998                             288.0                               1.0
# 5204                                41.0                               1.0
# 36638                               41.0                               1.0
# ...                                  ...                               ...
# 179868                              84.0                               1.0
# 179871                              84.0                               1.0
# 179874                              84.0                               1.0
# 179881                              84.0                               1.0
# 179971                              84.0                               1.0
#
#         O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# 168926                            2000.0                              764.0
# 92787                             2000.0                              454.0
# 119998                            2000.0                              463.0
# 5204                              2000.0                             1210.0
# 36638                             2000.0                             1190.0
# ...                                  ...                                ...
# 179868                            2000.0                              770.0
# 179871                            2000.0                              771.0
# 179874                            2000.0                              770.0
# 179881                            2000.0                              765.0
# 179971                            2000.0                              768.0
#
#         O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# 168926                              152.0                             1.0
# 92787                                83.0                             8.0
# 119998                              120.0                           288.0
# 5204                                 76.0                             1.0
# 36638                               104.0                            31.0
# ...                                   ...                             ...
# 179868                              131.0                             1.0
# 179871                              128.0                             4.0
# 179874                              129.0                             1.0
# 179881                              130.0                             1.0
# 179971                              138.0                             1.0
#
#         O1_features.weighted_degrees.v  O1_features.weights.max  \
# 168926                             5.0                      5.0
# 92787                              9.0                      3.0
# 119998                             1.0                      2.0
# 5204                               1.0                      2.0
# 36638                              1.0                      2.0
# ...                                ...                      ...
# 179868                             1.0                      3.0
# 179871                             1.0                      3.0
# 179874                             1.0                      3.0
# 179881                             3.0                      3.0
# 179971                             2.0                      3.0
#
#         O1_features.weights.med  O1_features.weights.tot  \
# 168926                      1.0                   1000.0
# 92787                       1.0                   1000.0
# 119998                      1.0                   1000.0
# 5204                        1.0                   1000.0
# 36638                       1.0                   1000.0
# ...                         ...                      ...
# 179868                      1.0                   1000.0
# 179871                      1.0                   1000.0
# 179874                      1.0                   1000.0
# 179881                      1.0                   1000.0
# 179971                      1.0                   1000.0
#
#         O1_features.weights.nb_1  O1_features.weights.nb_2  \
# 168926                     848.0                      64.0
# 92787                      835.0                      75.0
# 119998                     772.0                     114.0
# 5204                       996.0                       2.0
# 36638                      998.0                       1.0
# ...                          ...                       ...
# 179868                     856.0                      60.0
# 179871                     856.0                      60.0
# 179874                     856.0                      60.0
# 179881                     856.0                      60.0
# 179971                     860.0                      58.0
#
#         O1_features.weight  is_fraud
# 168926                 1.0         0
# 92787                  1.0         0
# 119998                 1.0         0
# 5204                   1.0         0
# 36638                  1.0         0
# ...                    ...       ...
# 179868                 1.0         1
# 179871                 1.0         1
# 179874                 1.0         1
# 179881                 1.0         1
# 179971                 1.0         1
#
# [17140 rows x 23 columns]

# %% [markdown]
# Author: Now the rows of the `nonanomalous` are random

# %%
# Now we will check deeper the values on the new dataset and compare them
new_dataset["is_fraud"].value_counts()
# Out:
# 0    8570
# 1    8570
# Name: is_fraud, dtype: int64

# %%
new_dataset.groupby("is_fraud").mean()
# Out:
#           O1_features.n  O1_features.m  O1_features.degrees.max  \
# is_fraud
# 0           1038.332205     955.389615                82.109685
# 1            890.296733     911.281914                70.977013
#
#           O1_features.degrees.med  O1_features.degrees.tot  \
# is_fraud
# 0                        1.019953              1910.779230
# 1                        1.007585              1822.563827
#
#           O1_features.degrees.nb_1  O1_features.degrees.nb_2  \
# is_fraud
# 0                       836.592532                100.541190
# 1                       660.573046                101.048308
#
#           O1_features.degrees.u  O1_features.degrees.v  \
# is_fraud
# 0                     16.155659              12.404784
# 1                      1.150642               1.141774
#
#           O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# is_fraud
# 0                                90.680280                          1.023571
# 1                                85.356709                          1.007935
#
#           O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# is_fraud
# 0                                   2000.0                         823.181330
# 1                                   2000.0                         631.862194
#
#           O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# is_fraud
# 0                                105.723921                       17.587981
# 1                                113.039907                        1.169778
#
#           O1_features.weighted_degrees.v  O1_features.weights.max  \
# is_fraud
# 0                              13.556009                 2.515519
# 1                               1.155426                 3.446091
#
#           O1_features.weights.med  O1_features.weights.tot  \
# is_fraud
# 0                             1.0                   1000.0
# 1                             1.0                   1000.0
#
#           O1_features.weights.nb_1  O1_features.weights.nb_2  \
# is_fraud
# 0                       913.737223                 38.946441
# 1                       830.141890                 74.317503
#
#           O1_features.weight
# is_fraud
# 0                   1.067445
# 1                   1.000117

# %% [markdown]
# The deviations still exist and thus the nature of the dataset hasn't changed in the undersampling.

# %%
# Drop O1_features.cost and Ok_features.cost features

# %%
# Shuffle the dataframe
new_dataset = new_dataset.sample(frac=1)
new_dataset
# Out:
#         O1_features.n  O1_features.m  O1_features.degrees.max  \
# 163969         1022.0          937.0                     26.0
# 111619          812.0          963.0                     85.0
# 79866           748.0          840.0                    144.0
# 171703         1067.0          914.0                     25.0
# 77847           630.0          888.0                     72.0
# ...               ...            ...                      ...
# 163834         1035.0          940.0                     24.0
# 91879           702.0          889.0                     30.0
# 17109          1354.0          998.0                     53.0
# 167386          965.0          885.0                     71.0
# 99886           815.0          872.0                    150.0
#
#         O1_features.degrees.med  O1_features.degrees.tot  \
# 163969                      1.0                   1874.0
# 111619                      1.0                   1926.0
# 79866                       1.0                   1680.0
# 171703                      1.0                   1828.0
# 77847                       1.0                   1776.0
# ...                         ...                      ...
# 163834                      1.0                   1880.0
# 91879                       1.0                   1778.0
# 17109                       1.0                   1996.0
# 167386                      1.0                   1770.0
# 99886                       1.0                   1744.0
#
#         O1_features.degrees.nb_1  O1_features.degrees.nb_2  \
# 163969                     755.0                     115.0
# 111619                     626.0                      89.0
# 79866                      580.0                      79.0
# 171703                     831.0                     114.0
# 77847                      409.0                      71.0
# ...                          ...                       ...
# 163834                     752.0                     134.0
# 91879                      498.0                      68.0
# 17109                     1183.0                      95.0
# 167386                     746.0                     102.0
# 99886                      612.0                      85.0
#
#         O1_features.degrees.u  O1_features.degrees.v  \
# 163969                    1.0                    2.0
# 111619                    1.0                    1.0
# 79866                     1.0                    1.0
# 171703                    1.0                    1.0
# 77847                     1.0                    1.0
# ...                       ...                    ...
# 163834                    1.0                    1.0
# 91879                     1.0                    1.0
# 17109                     3.0                    1.0
# 167386                    1.0                    2.0
# 99886                     1.0                    1.0
#
#         O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# 163969                              28.0                               1.0
# 111619                              90.0                               1.0
# 79866                              204.0                               1.0
# 171703                              28.0                               1.0
# 77847                               94.0                               1.0
# ...                                  ...                               ...
# 163834                              25.0                               1.0
# 91879                               42.0                               1.0
# 17109                               53.0                               1.0
# 167386                              80.0                               1.0
# 99886                              204.0                               1.0
#
#         O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# 163969                            2000.0                              724.0
# 111619                            2000.0                              605.0
# 79866                             2000.0                              495.0
# 171703                            2000.0                              807.0
# 77847                             2000.0                              399.0
# ...                                  ...                                ...
# 163834                            2000.0                              722.0
# 91879                             2000.0                              472.0
# 17109                             2000.0                             1181.0
# 167386                            2000.0                              693.0
# 99886                             2000.0                              562.0
#
#         O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# 163969                              133.0                             1.0
# 111619                              104.0                             1.0
# 79866                               136.0                             1.0
# 171703                              115.0                             1.0
# 77847                                68.0                             1.0
# ...                                   ...                             ...
# 163834                              151.0                             1.0
# 91879                                82.0                             1.0
# 17109                                97.0                             3.0
# 167386                              127.0                             1.0
# 99886                               116.0                             1.0
#
#         O1_features.weighted_degrees.v  O1_features.weights.max  \
# 163969                             2.0                      4.0
# 111619                             1.0                      2.0
# 79866                              1.0                      3.0
# 171703                             1.0                      3.0
# 77847                              1.0                      4.0
# ...                                ...                      ...
# 163834                             1.0                      4.0
# 91879                              1.0                      4.0
# 17109                              1.0                      2.0
# 167386                             2.0                      4.0
# 99886                              1.0                      3.0
#
#         O1_features.weights.med  O1_features.weights.tot  \
# 163969                      1.0                   1000.0
# 111619                      1.0                   1000.0
# 79866                       1.0                   1000.0
# 171703                      1.0                   1000.0
# 77847                       1.0                   1000.0
# ...                         ...                      ...
# 163834                      1.0                   1000.0
# 91879                       1.0                   1000.0
# 17109                       1.0                   1000.0
# 167386                      1.0                   1000.0
# 99886                       1.0                   1000.0
#
#         O1_features.weights.nb_1  O1_features.weights.nb_2  \
# 163969                     879.0                      54.0
# 111619                     926.0                      37.0
# 79866                      686.0                     148.0
# 171703                     834.0                      74.0
# 77847                      786.0                      94.0
# ...                          ...                       ...
# 163834                     885.0                      51.0
# 91879                      784.0                     100.0
# 17109                      996.0                       2.0
# 167386                     798.0                      60.0
# 99886                      758.0                     100.0
#
#         O1_features.weight  is_fraud
# 163969                 1.0         1
# 111619                 1.0         0
# 79866                  1.0         1
# 171703                 1.0         1
# 77847                  1.0         1
# ...                    ...       ...
# 163834                 1.0         1
# 91879                  1.0         1
# 17109                  1.0         0
# 167386                 1.0         1
# 99886                  1.0         1
#
# [17140 rows x 23 columns]

# %% [markdown]
# ### KFold in action

# %%
# KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
X = new_dataset.drop(columns="is_fraud", axis=1)
Y = new_dataset["is_fraud"]
clf = RandomForestClassifier(random_state=12)

# %%
X
# Out:
#         O1_features.n  O1_features.m  O1_features.degrees.max  \
# 163969         1022.0          937.0                     26.0
# 111619          812.0          963.0                     85.0
# 79866           748.0          840.0                    144.0
# 171703         1067.0          914.0                     25.0
# 77847           630.0          888.0                     72.0
# ...               ...            ...                      ...
# 163834         1035.0          940.0                     24.0
# 91879           702.0          889.0                     30.0
# 17109          1354.0          998.0                     53.0
# 167386          965.0          885.0                     71.0
# 99886           815.0          872.0                    150.0
#
#         O1_features.degrees.med  O1_features.degrees.tot  \
# 163969                      1.0                   1874.0
# 111619                      1.0                   1926.0
# 79866                       1.0                   1680.0
# 171703                      1.0                   1828.0
# 77847                       1.0                   1776.0
# ...                         ...                      ...
# 163834                      1.0                   1880.0
# 91879                       1.0                   1778.0
# 17109                       1.0                   1996.0
# 167386                      1.0                   1770.0
# 99886                       1.0                   1744.0
#
#         O1_features.degrees.nb_1  O1_features.degrees.nb_2  \
# 163969                     755.0                     115.0
# 111619                     626.0                      89.0
# 79866                      580.0                      79.0
# 171703                     831.0                     114.0
# 77847                      409.0                      71.0
# ...                          ...                       ...
# 163834                     752.0                     134.0
# 91879                      498.0                      68.0
# 17109                     1183.0                      95.0
# 167386                     746.0                     102.0
# 99886                      612.0                      85.0
#
#         O1_features.degrees.u  O1_features.degrees.v  \
# 163969                    1.0                    2.0
# 111619                    1.0                    1.0
# 79866                     1.0                    1.0
# 171703                    1.0                    1.0
# 77847                     1.0                    1.0
# ...                       ...                    ...
# 163834                    1.0                    1.0
# 91879                     1.0                    1.0
# 17109                     3.0                    1.0
# 167386                    1.0                    2.0
# 99886                     1.0                    1.0
#
#         O1_features.weighted_degrees.max  O1_features.weighted_degrees.med  \
# 163969                              28.0                               1.0
# 111619                              90.0                               1.0
# 79866                              204.0                               1.0
# 171703                              28.0                               1.0
# 77847                               94.0                               1.0
# ...                                  ...                               ...
# 163834                              25.0                               1.0
# 91879                               42.0                               1.0
# 17109                               53.0                               1.0
# 167386                              80.0                               1.0
# 99886                              204.0                               1.0
#
#         O1_features.weighted_degrees.tot  O1_features.weighted_degrees.nb_1  \
# 163969                            2000.0                              724.0
# 111619                            2000.0                              605.0
# 79866                             2000.0                              495.0
# 171703                            2000.0                              807.0
# 77847                             2000.0                              399.0
# ...                                  ...                                ...
# 163834                            2000.0                              722.0
# 91879                             2000.0                              472.0
# 17109                             2000.0                             1181.0
# 167386                            2000.0                              693.0
# 99886                             2000.0                              562.0
#
#         O1_features.weighted_degrees.nb_2  O1_features.weighted_degrees.u  \
# 163969                              133.0                             1.0
# 111619                              104.0                             1.0
# 79866                               136.0                             1.0
# 171703                              115.0                             1.0
# 77847                                68.0                             1.0
# ...                                   ...                             ...
# 163834                              151.0                             1.0
# 91879                                82.0                             1.0
# 17109                                97.0                             3.0
# 167386                              127.0                             1.0
# 99886                               116.0                             1.0
#
#         O1_features.weighted_degrees.v  O1_features.weights.max  \
# 163969                             2.0                      4.0
# 111619                             1.0                      2.0
# 79866                              1.0                      3.0
# 171703                             1.0                      3.0
# 77847                              1.0                      4.0
# ...                                ...                      ...
# 163834                             1.0                      4.0
# 91879                              1.0                      4.0
# 17109                              1.0                      2.0
# 167386                             2.0                      4.0
# 99886                              1.0                      3.0
#
#         O1_features.weights.med  O1_features.weights.tot  \
# 163969                      1.0                   1000.0
# 111619                      1.0                   1000.0
# 79866                       1.0                   1000.0
# 171703                      1.0                   1000.0
# 77847                       1.0                   1000.0
# ...                         ...                      ...
# 163834                      1.0                   1000.0
# 91879                       1.0                   1000.0
# 17109                       1.0                   1000.0
# 167386                      1.0                   1000.0
# 99886                       1.0                   1000.0
#
#         O1_features.weights.nb_1  O1_features.weights.nb_2  O1_features.weight
# 163969                     879.0                      54.0                 1.0
# 111619                     926.0                      37.0                 1.0
# 79866                      686.0                     148.0                 1.0
# 171703                     834.0                      74.0                 1.0
# 77847                      786.0                      94.0                 1.0
# ...                          ...                       ...                 ...
# 163834                     885.0                      51.0                 1.0
# 91879                      784.0                     100.0                 1.0
# 17109                      996.0                       2.0                 1.0
# 167386                     798.0                      60.0                 1.0
# 99886                      758.0                     100.0                 1.0
#
# [17140 rows x 22 columns]

# %%
Y
# Out:
# 163969    1
# 111619    0
# 79866     1
# 171703    1
# 77847     1
#          ..
# 163834    1
# 91879     1
# 17109     0
# 167386    1
# 99886     1
# Name: is_fraud, Length: 17140, dtype: int64

# %%
cv_accuracy = cross_val_score(clf, X, Y, cv=10, scoring="accuracy")
#print("All accuracy:", cv_accuracy)
print("Mean accuracy:", round(np.mean(cv_accuracy), 4))

cv_precision = cross_val_score(clf, X, Y, cv=10, scoring="precision")
#print("All precision:", cv_precision)
print("Mean precision:", round(np.mean(cv_precision),4))

cv_recall = cross_val_score(clf, X, Y, cv=10, scoring="recall")
#print("All recall:", cv_recall)
print("Mean recall:", round(np.mean(cv_recall),4))

cv_f1 = cross_val_score(clf, X, Y, cv=10, scoring="f1")
#print("All f1:", cv_f1)
print("Mean f1:", round(np.mean(cv_f1),4))

cv_roc_auc = cross_val_score(clf, X, Y, cv=10, scoring="roc_auc")
#print("All roc_auc:", cv_roc_auc)
print("Mean roc_auc:", round(np.mean(cv_roc_auc),4))
# Out:
# Mean accuracy: 0.9481
# Mean precision: 0.9392
# Mean recall: 0.9582
# Mean f1: 0.9486
# Mean roc_auc: 0.9812

# %%
y = Y

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.metrics import roc_curve, auc,roc_auc_score
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold

# %%
data = datasets.load_breast_cancer()
X1 = data.data
y1 = data.target

print(X1.shape)
print(y1.shape)
# Out:
# (569, 30)
# (569,)

# %%
type(X1)
# Out:
# numpy.ndarray

# %%
type(y1)
# Out:
# numpy.ndarray

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
y_ndarray = y.to_numpy()
y_ndarray
# Out:
# array([1, 0, 1, ..., 0, 1, 1], dtype=int64)

# %%
X_ndarray = X.to_numpy()
X_ndarray
# Out:
# array([[1.022e+03, 9.370e+02, 2.600e+01, ..., 8.790e+02, 5.400e+01,
#         1.000e+00],
#        [8.120e+02, 9.630e+02, 8.500e+01, ..., 9.260e+02, 3.700e+01,
#         1.000e+00],
#        [7.480e+02, 8.400e+02, 1.440e+02, ..., 6.860e+02, 1.480e+02,
#         1.000e+00],
#        ...,
#        [1.354e+03, 9.980e+02, 5.300e+01, ..., 9.960e+02, 2.000e+00,
#         1.000e+00],
#        [9.650e+02, 8.850e+02, 7.100e+01, ..., 7.980e+02, 6.000e+01,
#         1.000e+00],
#        [8.150e+02, 8.720e+02, 1.500e+02, ..., 7.580e+02, 1.000e+02,
#         1.000e+00]])

# %%
cross_val = KFold(n_splits=6, random_state=42, shuffle=True)
model = LogisticRegression()

# %%
tprs, aucs = [], []
mean_fpr = np.linspace(0, 1, 100)

# %%
fig, ax = plt.subplots()
for index, (train, test) in enumerate(cross_val.split(X_ndarray, y_ndarray)):
	model.fit(X_ndarray[train], y_ndarray[train])
	plot = RocCurveDisplay.from_estimator(
		model, X_ndarray[test], y_ndarray[test],
		name="ROC fold {}".format(index),
		ax=ax,
	)
	interp_tpr = np.interp(mean_fpr, plot.fpr, plot.tpr)
	interp_tpr[0] = 0.0
	tprs.append(interp_tpr)
	aucs.append(plot.roc_auc)

ax.set(
	xlim=[-0.05, 1.05],
	ylim=[-0.05, 1.05],
	title="Receiver operating characteristic with CV",
)
plt.savefig("roc_cv.jpeg")
# Out:
# C:\Users\steph\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\steph\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\steph\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\steph\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\steph\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\steph\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold


clf = RandomForestClassifier(random_state=12)
cv = 10

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10, 10))

for i, (train, test) in enumerate(StratifiedKFold(n_splits=cv).split(X_ndarray, y_ndarray)):
    clf.fit(X_ndarray[train], y_ndarray[train])
    viz = RocCurveDisplay.from_estimator(clf, X_ndarray[test], y_ndarray[test], ax=ax, name='ROC fold {}'.format(i))
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', alpha=.8)
mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)

ax.plot(mean_fpr, mean_tpr, color='b', label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc), lw=2, alpha=.8)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)

ax.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2, label=r'$\pm$ 1 std. dev.')

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05], title="Receiver operating characteristic example")
ax.legend(loc="lower right")

plt.show()

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(random_state=12)
y_pred = cross_val_predict(clf, X, y, cv=10)
cm = confusion_matrix(y, y_pred)
print(cm)
# Out:
# [[8038  532]
#  [ 358 8212]]

# %% [raw]
# 1) How to interpret:
# [[212  29]
#  [ 19 222]]
# This is a confusion matrix with two classes, often used to evaluate the performance of a binary classification model. The columns represent the predicted classes, and the rows represent the actual classes.
#
# In this case, the matrix is of size 2x2 because there are two classes. The class in the first row and first column is the true negative (TN), meaning that the actual class was negative and the model correctly predicted it to be negative. The second row and second column represent the true positive (TP), where the actual class was positive and the model correctly predicted it to be positive.
#
# The numbers in the other cells represent the false positive (FP) and false negative (FN) classifications. FP is when the model predicts a positive class, but the actual class is negative. FN is when the model predicts a negative class, but the actual class is positive.
#
# In this specific case, the confusion matrix indicates that the model predicted 212 true negatives and 222 true positives, while incorrectly predicting 29 false positives and 19 false negatives.
#
#
#
# 2) Does this mean our classifier is good?
# A confusion matrix alone is not sufficient to determine if a classifier is good or not. It depends on the specific problem and the goals of the classification task.
#
# However, a high number of true positives and true negatives (in the top left and bottom right cells) and a low number of false positives and false negatives (in the bottom left and top right cells) generally indicate good performance of the classifier.
#
# In the given confusion matrix, there are a high number of true positives and true negatives, which is generally a good sign. However, without more information about the problem and the goals of the classification task, it is not possible to definitively say whether the classifier is good or not.

# %%
kf = KFold(n_splits=10, shuffle=True, random_state=42)
for train_index, test_index in kf.split(X_ndarray):
    X_train, X_test = X_ndarray[train_index], X_ndarray[test_index]
    y_train, y_test = y_ndarray[train_index], y_ndarray[test_index]
    
    # Fit the model on the training data
    clf.fit(X_train, y_train)
    
    # Predict on the test data
    y_pred = clf.predict(X_test)
    
    # Compare the predicted labels to the true labels
    print("Pred labels:", y_pred)
    print("True labels:", y_test)
    print("=======================")
# Out:
# Pred labels: [1 1 1 ... 0 0 1]
# True labels: [1 1 1 ... 0 0 1]
# =======================
# Pred labels: [1 1 0 ... 1 1 1]
# True labels: [1 1 0 ... 1 1 1]
# =======================
# Pred labels: [0 0 1 ... 0 1 1]
# True labels: [0 0 1 ... 0 1 1]
# =======================
# Pred labels: [0 1 1 ... 0 0 1]
# True labels: [0 0 1 ... 0 0 1]
# =======================
# Pred labels: [1 0 0 ... 1 0 1]
# True labels: [1 0 0 ... 1 0 1]
# =======================
# Pred labels: [1 0 0 ... 1 0 1]
# True labels: [1 0 0 ... 0 0 1]
# =======================
# Pred labels: [0 0 1 ... 1 0 1]
# True labels: [0 0 1 ... 1 0 1]
# =======================
# Pred labels: [1 1 1 ... 1 1 1]
# True labels: [1 1 1 ... 1 1 1]
# =======================
# Pred labels: [0 0 0 ... 0 0 0]
# True labels: [0 0 0 ... 0 0 0]
# =======================
# Pred labels: [0 0 1 ... 1 1 0]
# True labels: [0 0 1 ... 1 1 0]
# =======================

# %% [markdown]
# ### Interpretation using permutation feature importance
#
# Permutation feature importance measures the importance of a feature by looking at how much the error increases after we change the feature values. The feature is important if the change of its value increases the model’s error.
#
# To implement this method, we can use a function called permutation_importance from the scikit-learn library to calculate the feature importance. From that result, we will create a boxplot to visualize the feature importance.
#
# Source: https://towardsdatascience.com/how-to-remove-multicollinearity-using-python-4da8d9d8abb2

# %%
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify = Y, random_state = 12)

print(X.shape, X_train.shape, X_test.shape)
# Out:
# (17140, 22) (13712, 22) (3428, 22)

# %%
model = RandomForestClassifier(random_state=12)
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=12)

# %%
model.score(X_test, Y_test)
# Out:
# 0.9509918319719953

# %%
result = permutation_importance(model, X_train, Y_train, n_repeats=10, random_state=12)

perm_imp_idx = result.importances_mean.argsort()
plt.boxplot(result.importances[perm_imp_idx].T, vert=False,
            labels=X.columns[perm_imp_idx])
plt.title('Feature Importance in UCI-H1000-O1 with RandomForestClassifier', fontweight="bold")
plt.show()

# %% [markdown]
# ### Interpretation using the returned estimators

# %%
# https://stackoverflow.com/questions/55466081/how-to-calculate-feature-importance-in-each-models-of-cross-validation-in-sklear
from sklearn.model_selection import cross_validate
import random

clf=RandomForestClassifier(random_state=12)
output = cross_validate(clf, X, Y, cv=10, scoring = 'roc_auc', return_estimator =True)

df = pd.DataFrame()
for idx,estimator in enumerate(output['estimator']):
    print("Features sorted by their score for estimator {}:".format(idx))
    feature_importances = pd.DataFrame(estimator.feature_importances_,
                                       index=X.columns,
                                        columns=['importance']).sort_values('importance', ascending=False)
    df = pd.concat([df, feature_importances], axis=1)
# Out:
# Features sorted by their score for estimator 0:
# Features sorted by their score for estimator 1:
# Features sorted by their score for estimator 2:
# Features sorted by their score for estimator 3:
# Features sorted by their score for estimator 4:
# Features sorted by their score for estimator 5:
# Features sorted by their score for estimator 6:
# Features sorted by their score for estimator 7:
# Features sorted by their score for estimator 8:
# Features sorted by their score for estimator 9:

# %%
df
# Out:
#                                    importance  importance  importance  \
# O1_features.weighted_degrees.u       0.162092    0.159908    0.158728
# O1_features.weighted_degrees.v       0.116627    0.116916    0.123479
# O1_features.degrees.u                0.106849    0.109880    0.107593
# O1_features.degrees.v                0.082599    0.086409    0.078710
# O1_features.degrees.tot              0.080603    0.086962    0.087260
# O1_features.m                        0.080528    0.081985    0.086047
# O1_features.weights.max              0.067263    0.064039    0.062096
# O1_features.weights.nb_2             0.053583    0.047325    0.051035
# O1_features.weights.nb_1             0.045187    0.045798    0.045800
# O1_features.degrees.nb_1             0.043221    0.043094    0.044757
# O1_features.n                        0.039559    0.033741    0.033942
# O1_features.weighted_degrees.nb_1    0.036870    0.038895    0.033747
# O1_features.degrees.max              0.022942    0.023575    0.024974
# O1_features.weighted_degrees.max     0.019657    0.019097    0.019721
# O1_features.degrees.nb_2             0.019297    0.018954    0.017533
# O1_features.weighted_degrees.nb_2    0.017693    0.017502    0.018456
# O1_features.weight                   0.005188    0.005713    0.005776
# O1_features.degrees.med              0.000131    0.000072    0.000153
# O1_features.weighted_degrees.med     0.000110    0.000135    0.000192
# O1_features.weights.med              0.000000    0.000000    0.000000
# O1_features.weights.tot              0.000000    0.000000    0.000000
# O1_features.weighted_degrees.tot     0.000000    0.000000    0.000000
#
#                                    importance  importance  importance  \
# O1_features.weighted_degrees.u       0.147739    0.144493    0.159427
# O1_features.weighted_degrees.v       0.115651    0.119087    0.106975
# O1_features.degrees.u                0.111824    0.116912    0.113521
# O1_features.degrees.v                0.086668    0.086104    0.081536
# O1_features.degrees.tot              0.078145    0.076305    0.092099
# O1_features.m                        0.088446    0.087315    0.075921
# O1_features.weights.max              0.067710    0.066150    0.065376
# O1_features.weights.nb_2             0.052722    0.050347    0.051914
# O1_features.weights.nb_1             0.045345    0.046631    0.045964
# O1_features.degrees.nb_1             0.044567    0.045330    0.043789
# O1_features.n                        0.036995    0.036266    0.034038
# O1_features.weighted_degrees.nb_1    0.035373    0.036375    0.039795
# O1_features.degrees.max              0.025713    0.024911    0.023953
# O1_features.weighted_degrees.max     0.020434    0.020401    0.020502
# O1_features.degrees.nb_2             0.018648    0.019091    0.018984
# O1_features.weighted_degrees.nb_2    0.018248    0.018777    0.019217
# O1_features.weight                   0.005506    0.005213    0.006397
# O1_features.degrees.med              0.000123    0.000128    0.000277
# O1_features.weighted_degrees.med     0.000142    0.000163    0.000316
# O1_features.weights.med              0.000000    0.000000    0.000000
# O1_features.weights.tot              0.000000    0.000000    0.000000
# O1_features.weighted_degrees.tot     0.000000    0.000000    0.000000
#
#                                    importance  importance  importance  \
# O1_features.weighted_degrees.u       0.151368    0.147341    0.156064
# O1_features.weighted_degrees.v       0.121710    0.135571    0.115914
# O1_features.degrees.u                0.122336    0.116559    0.111419
# O1_features.degrees.v                0.081263    0.069207    0.080496
# O1_features.degrees.tot              0.086390    0.086557    0.088821
# O1_features.m                        0.079682    0.074002    0.080590
# O1_features.weights.max              0.049082    0.062605    0.061442
# O1_features.weights.nb_2             0.049512    0.045669    0.048185
# O1_features.weights.nb_1             0.057354    0.058401    0.051638
# O1_features.degrees.nb_1             0.044112    0.047767    0.046227
# O1_features.n                        0.032897    0.035771    0.034596
# O1_features.weighted_degrees.nb_1    0.038728    0.035336    0.037045
# O1_features.degrees.max              0.022996    0.023264    0.023858
# O1_features.weighted_degrees.max     0.020000    0.020350    0.020546
# O1_features.degrees.nb_2             0.018511    0.018733    0.018895
# O1_features.weighted_degrees.nb_2    0.018829    0.018095    0.017447
# O1_features.weight                   0.004783    0.004520    0.006413
# O1_features.degrees.med              0.000139    0.000081    0.000122
# O1_features.weighted_degrees.med     0.000308    0.000172    0.000282
# O1_features.weights.med              0.000000    0.000000    0.000000
# O1_features.weights.tot              0.000000    0.000000    0.000000
# O1_features.weighted_degrees.tot     0.000000    0.000000    0.000000
#
#                                    importance
# O1_features.weighted_degrees.u       0.152307
# O1_features.weighted_degrees.v       0.130485
# O1_features.degrees.u                0.104577
# O1_features.degrees.v                0.073512
# O1_features.degrees.tot              0.092030
# O1_features.m                        0.068354
# O1_features.weights.max              0.071030
# O1_features.weights.nb_2             0.047341
# O1_features.weights.nb_1             0.052559
# O1_features.degrees.nb_1             0.046874
# O1_features.n                        0.033717
# O1_features.weighted_degrees.nb_1    0.038565
# O1_features.degrees.max              0.024349
# O1_features.weighted_degrees.max     0.021012
# O1_features.degrees.nb_2             0.019075
# O1_features.weighted_degrees.nb_2    0.018034
# O1_features.weight                   0.005616
# O1_features.degrees.med              0.000091
# O1_features.weighted_degrees.med     0.000472
# O1_features.weights.med              0.000000
# O1_features.weights.tot              0.000000
# O1_features.weighted_degrees.tot     0.000000

# %%
df.plot(kind="bar", figsize=(20, 5))
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
